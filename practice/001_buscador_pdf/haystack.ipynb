# %% [markdown]
# ### Solución **Haystack**

# %%
import getpass
import os

if "LANGCHAIN_API_KEY" not in os.environ:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# #### A. Indexar

# %%
from haystack.components.writers import DocumentWriter
from haystack.components.converters import PyPDFToDocument, TextFileToDocument
from haystack.components.preprocessors import DocumentCleaner, DocumentSplitter
from haystack.components.routers import FileTypeRouter
from haystack.components.joiners import DocumentJoiner
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.embedders import SentenceTransformersDocumentEmbedder

document_store = InMemoryDocumentStore()

file_type_router = FileTypeRouter(mime_types = ["application/pdf", "text/plain"])
text_file_converter = TextFileToDocument()
pdf_converter = PyPDFToDocument()

document_joiner = DocumentJoiner()
document_cleaner = DocumentCleaner()
document_splitter = DocumentSplitter()

document_embedder = SentenceTransformersDocumentEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")
document_writer = DocumentWriter(document_store=document_store)

# %%
from haystack import Pipeline

index_pipeline = Pipeline()
index_pipeline.add_component(name="file_type_router", instance=file_type_router)
index_pipeline.add_component(name="text_file_converter", instance=text_file_converter)
index_pipeline.add_component(name="pdf_converter", instance=pdf_converter)
index_pipeline.add_component(name="document_joiner", instance=document_joiner)
index_pipeline.add_component(name="document_cleaner", instance=document_cleaner)
index_pipeline.add_component(name="document_splitter", instance=document_splitter)
index_pipeline.add_component(name="document_embedder", instance=document_embedder)
index_pipeline.add_component(name="document_writer", instance=document_writer)

index_pipeline.connect("file_type_router.text/plain", "text_file_converter.sources")
index_pipeline.connect("file_type_router.application/pdf", "pdf_converter.sources")
index_pipeline.connect("text_file_converter", "document_joiner")
index_pipeline.connect("pdf_converter", "document_joiner")
index_pipeline.connect("document_joiner", "document_cleaner")
index_pipeline.connect("document_cleaner", "document_splitter")
index_pipeline.connect("document_splitter", "document_embedder")
index_pipeline.connect("document_embedder", "document_writer")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7f8ee1866010>
# 🚅 Components
#   - file_type_router: FileTypeRouter
#   - text_file_converter: TextFileToDocument
#   - pdf_converter: PyPDFToDocument
#   - document_joiner: DocumentJoiner
#   - document_cleaner: DocumentCleaner
#   - document_splitter: DocumentSplitter
#   - document_embedder: SentenceTransformersDocumentEmbedder
#   - document_writer: DocumentWriter
# 🛤️ Connections
#   - file_type_router.text/plain -> text_file_converter.sources (List[Union[str, Path, ByteStream]])
#   - file_type_router.application/pdf -> pdf_converter.sources (List[Union[str, Path, ByteStream]])
#   - text_file_converter.documents -> document_joiner.documents (List[Document])
#   - pdf_converter.documents -> document_joiner.documents (List[Document])
#   - document_joiner.documents -> document_cleaner.documents (List[Document])
#   - document_cleaner.documents -> document_splitter.documents (List[Document])
#   - document_splitter.documents -> document_embedder.documents (List[Document])
#   - document_embedder.documents -> document_writer.documents (List[Document])

# %%
from pathlib import Path

output_dir = "./data"
list_docs = list(Path(output_dir).glob("**/*"))

index_pipeline.run({"file_type_router": {"sources": list_docs}})
# Out:
# /home/nahumfg/GithubProjects/TesisMaestria/PracticeLLMs/venv_haystack_ai/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:195: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v4 of SentenceTransformers.
#   warnings.warn(
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]
# {'document_writer': {'documents_written': 411}}

# %% [markdown]
# ### B. Retriever pipeline

# %%
from haystack.components.embedders import SentenceTransformersTextEmbedder
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.builders import PromptBuilder


ret_text_embedder = SentenceTransformersTextEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")
retriever = InMemoryEmbeddingRetriever(document_store=document_store)
ret_template = """
Dada la siguiente información, responde a la pregunta

Contexto:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

Pregunta:{{ question }}
Respuesta:
"""
ret_prompt_builder = PromptBuilder(template=ret_template)

# %%
from haystack import Pipeline

ret_pipeline = Pipeline()
ret_pipeline.add_component("text_embedder", ret_text_embedder)
ret_pipeline.add_component("retriever", retriever)
ret_pipeline.add_component("prompt_builder", ret_prompt_builder)

ret_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
ret_pipeline.connect("retriever", "prompt_builder.documents")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7f8e77980450>
# 🚅 Components
#   - text_embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
#   - prompt_builder: PromptBuilder
# 🛤️ Connections
#   - text_embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> prompt_builder.documents (List[Document])

# %%
from pprint import pprint

question = "Tienes el articulo Acceso de los grupos de interés a la arena gubernamental"

response = ret_pipeline.run({"text_embedder": {"text": question}, "prompt_builder": {"question": question}})
pprint(response)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'prompt_builder': {'prompt': '\n'
#                               'Dada la siguiente información, responde a la '
#                               'pregunta\n'
#                               '\n'
#                               'Contexto:\n'
#                               '\n'
#                               '    del Gobierno 35 1,5\n'
#                               'Vicepresidenta del Gobierno 6 0,3\n'
#                               'Interior Interior 108 4,5\n'
#                               'Justicia Justicia 230 9,5\n'
#                               'Salud\n'
#                               'Sanidad 28 1,2\n'
#                               'Sanidad, Consumo y Bienestar Social 75 3,1\n'
#                               'Sanidad, Servicios Sociales e Igualdad 89 3,7\n'
#                               'Trabajo\n'
#                               'Empleo y Seguridad Social 16 0,7\n'
#                               'Empleo y Seguridad Social 33 1,4\n'
#                               'Inclusión, Seguridad Social y Migraciones 41 '
#                               '1,7\n'
#                               'Trabajo y Economía Social 76 3,2\n'
#                               'Trabajo, Migraciones y Seguridad Social 22 0,9\n'
#                               'Transporte Fomento 15 0,6\n'
#                               'Transportes, Movilidad y Agenda Urbana 6 0,2\n'
#                               'Total 2.409 100,0\n'
#                               'Fuente: Elaboración propia.\x0c'
#                               'Reis. Rev.Esp.Investig.Sociol. ISSN-L: '
#                               '0210-5233. N.º 186, Abril - Junio 2024, pp.\xa0'
#                               '123-142\n'
#                               '132 Acceso de los grupos de interés a la arena '
#                               'gubernamental\n'
#                               'Para realizar el análisis también se han '
#                               'clasificado los ministerios de acuerdo con sus '
#                               'áreas temáticas —de acuerdo con la metodo-\n'
#                               'logía del Comparative Agendas Project— para '
#                               'cada legislatura entre 2011 y 2021, tal y como '
#                               'resume la tabla 2. Entre 2012 y 2021 el nú-\n'
#                               'mero de ministerios aumenta de 14 ministe-\n'
#                               'rios bajo los gobiernos liderados por Mariano '
#                               'Rajoy a 21 ministerios durante el período del '
#                               'gobierno de coalición PSOE-Unidas Pode-\n'
#                               'mos. Los gobiernos del Partido Popular re-\n'
#                               'flejan un perfil tecnocrático y la voluntad de '
#                               'concentrar las competencias del Ejecutivo en '
#                               'megaministerios. Por ejemplo, José Ignacio Wert '
#                               'fue responsable del Ministerio de Edu-\n'
#                               'cación, Cultura y Deporte; José Manuel Soria se '
#                               'encargó del Ministerio de Industria, \n'
#                               '\n'
#                               '    intercambio y de la agenda; segundo, '
#                               'explicamos la estrategia metodológica planteada '
#                               'en el artículo en la que se detalla la '
#                               'recopilación y clasificación de datos, así como '
#                               'un breve comentario so-\n'
#                               'bre la situación política que caracterizó el '
#                               'periodo de estudio; tercero, se analiza el '
#                               'acceso de los grupos de interés al Gobierno '
#                               'central siguiendo el orden de las hipóte-\n'
#                               'sis planteadas durante la discusión teórica; y '
#                               'cuarto, en las conclusiones, se discute el '
#                               'estado de la cuestión y las líneas futuras de '
#                               'investigación sobre el acceso de los grupos de '
#                               'interés al Gobierno en España.\n'
#                               'InformacIón y acceso al\xa0proceso polítIco\n'
#                               'De acuerdo con el enfoque del intercam-\n'
#                               'bio, el acceso de los grupos de interés a la '
#                               'arena gubernamental se explica a par-\n'
#                               'tir de su capacidad para proporcionar bie -\n'
#                               'nes e información que los miembros del go-\n'
#                               'bierno necesitan (Beyers, Bruycker y Baller, '
#                               '2015). La complejidad en la dirección y ges-\n'
#                               'tión de los asuntos públicos hace necesario que '
#                               'políticos y gobernantes interactúen con '
#                               'organizaciones privadas —como sindica -\n'
#                               'tos, colegios profesionales, organizaciones '
#                               'empresariales, organizaciones no guber-\n'
#                               'namentales, o think tanks— para resolver '
#                               'problemas públicos (Chaqués-Bonafont, 2004). '
#                               'Para regular e implementar políticas que '
#                               'afectan a sectores económicos, desde el cultivo '
#                               'del lino a las nuevas tecnologías de la \n'
#                               '\n'
#                               '    Artículo 1: Acceso de los grupos de interés '
#                               'a la arena gubernamental Autores: Iván Medina y '
#                               'Laura Chaqués-Bonafont Resumen: Este estudio '
#                               'compara el acceso de los grupos de interés al '
#                               'gobierno durante los mandatos de Mariano Rajoy '
#                               'y Pedro Sánchez (2012-2021), utilizando una '
#                               'base de datos de 2409 reuniones bilaterales. '
#                               'Los resultados muestran que los grupos '
#                               'empresariales tuvieron mayor acceso en '
#                               'comparación con otros grupos, con variaciones '
#                               'según áreas políticas y la ideología del '
#                               'partido en el poder. Bajo el gobierno de '
#                               'coalición PSOE-UP, se observó mayor interacción '
#                               'con sindicatos y ONG. Palabras clave: Agendas, '
#                               'asociaciones empresariales, gobierno, grupos de '
#                               'interés, ONG, sindicatos. Artículo 2: '
#                               'Asociacionismo, capital social y género en la '
#                               'sociedad española Autores: Loreto Vázquez-Chas '
#                               'y José Atilano Pena-López Resumen: Este trabajo '
#                               'analiza la participación asociativa en España '
#                               'desde una perspectiva de género, abordando '
#                               'equidad vertical (niveles de participación) y '
#                               'horizontal (tipos de asociaciones). A través de '
#                               'datos de la Encuesta sobre el Capital Social '
#                               '(2019), se concluye que los roles de género '
#                               'limitan la participación política, '
#                               'especialmente en el asociacionismo político, '
#                               'perpetuando desigualdades de confianza y '
#                               'participación social. Palabras clave: Capital '
#                               'social, confianza general, género, '
#                               'participación asociativa. Artículo 3: ¿El '
#                               'género hace la diferencia? Perfiles de '
#                               'carrera \n'
#                               '\n'
#                               '    tipo de grupos de interés se reúnen con los '
#                               'miembros del Go-\n'
#                               'bierno en España entre 2012 y 2021. El es-\n'
#                               'tudio se centra en las reuniones bilaterales de '
#                               'carácter informal que mantienen los mi-\n'
#                               'nistros y las ministras con grupos empre-\n'
#                               'sariales, sindicatos, ONG, organizaciones de '
#                               'profesionales y otros grupos de interés de '
#                               'carácter institucional. De acuerdo con el '
#                               'enfoque del intercambio (Bouwen, 2004), el '
#                               'acceso de los grupos de interés a la arena '
#                               'gubernamental se explica a partir de su ca-\n'
#                               'pacidad de proporcionar la información téc-\n'
#                               'nica que necesitan (Hall y Deardorff, 2006; '
#                               'Binderkrantz, Christiansen y Pedersen, 2015; '
#                               'Dür y Mateo, 2016). Estos estudios enfatizan '
#                               'que las organizaciones de carác-\n'
#                               'ter económico —asociaciones empresaria-\n'
#                               'les y sindicatos— participan con más inten-\n'
#                               'sidad que cualquier otro grupo de interés (las '
#                               'asociaciones cívicas y humanitarias, por '
#                               'ejemplo) en la arena gubernamental por-\n'
#                               'que pueden dar respuesta a los fallos de '
#                               'información de los miembros del Gobierno de '
#                               'forma comprensiva a lo largo del ciclo de las '
#                               'políticas públicas (Beyers y Braun, 2014). '
#                               'Patronales y sindicatos aportan in-\n'
#                               'formación técnica especializada durante la fase '
#                               'de definición de la agenda y formula-\n'
#                               'ción de alternativas y contribuyen al pro-\n'
#                               'ceso de elaboración de textos legislativos, así '
#                               'como a la implementación y evaluación de '
#                               'políticas \n'
#                               '\n'
#                               '    concretas. De forma comple-\n'
#                               'mentaria, los estudios de la agenda política '
#                               'enfatizan que el acceso a la arena guberna-\n'
#                               'mental varía en función de la capacidad de los '
#                               'grupos de interés de proporcionar ideas y '
#                               'formas de entender los problemas que respondan '
#                               'a las preferencias del Gobierno y contribuyan a '
#                               'legitimar su posición en el proceso político '
#                               'ante la prensa y la opinión pública '
#                               '(Baumgartner et\xa0al., 2009). Este trabajo se '
#                               'construye a partir de los estudios de la teoría '
#                               'del intercambio y de la dinámica de la agenda '
#                               'con el objetivo de ex-\n'
#                               'plicar las variaciones en el acceso a la arena '
#                               'gubernamental por tipo de grupo, área temá-\n'
#                               'tica y en el tiempo. ¿Se reúnen más los gru-\n'
#                               'pos empresariales con los miembros de los '
#                               'gobiernos liderados por el Partido Popular? '
#                               '¿Incrementan el número de reuniones entre los '
#                               'miembros del Gobierno y las ONG bajo los '
#                               'gobiernos liderados por el PSOE? ¿Exis-\n'
#                               'ten diferencias significativas por áreas temá-\n'
#                               'ticas? La estrategia empírica se desarrolla a '
#                               'partir de una base de datos original recopi-\n'
#                               'lada por el Grupo de Investigación sobre Ca-\n'
#                               'lidad de la Democracia (Q-Dem) que incluye 2409 '
#                               'reuniones bilaterales entre los sucesi-\n'
#                               'vos gobiernos centrales y grupos de interés '
#                               'durante el periodo 2012-2021. La base de '
#                               'datos \n'
#                               '\n'
#                               '    2024, pp.\xa0123-142\n'
#                               '136 Acceso de los grupos de interés a la arena '
#                               'gubernamental\n'
#                               'temas relativos a la función pública), Tra-\n'
#                               'bajo (29 %), Interior (26 %) y Economía y '
#                               'Hacienda (20 %). En conjunto, organiza-\n'
#                               'ciones empresariales y sindicatos suman el '
#                               '73\xa0% y 76\xa0% de las reuniones bilaterales '
#                               'entre grupos de interés y los ministerios que '
#                               'dirigen y gestionan los asuntos económicos y '
#                               'laborales. Por el contrario, el papel de or-\n'
#                               'ganizaciones empresariales es nulo en los temas '
#                               'de Defensa. Las asociaciones cívicas, '
#                               'identitarias y ONG ocupan un lugar predominante '
#                               'en las áreas de derechos (74\xa0% de las '
#                               'reuniones), salud (47 %), asuntos exteriores '
#                               '(39,5 %), interior (38\xa0%) y medio ambiente '
#                               '(29\xa0%). La mayoría de las reuniones en el '
#                               'ámbito de de-\n'
#                               'rechos (Ministerio de Igualdad, y Ministerio de '
#                               'Derechos Sociales y Agenda 2030) son con '
#                               'asociaciones vinculadas a temas de gé-\n'
#                               'nero; en el ámbito del Ministerio de Exterio-\n'
#                               'res, las reuniones son mayoritariamente con '
#                               'asociaciones humanitarias vinculadas a la '
#                               'cooperación internacional, mientras que la '
#                               'mayoría de las reuniones con el Ministerio de '
#                               'Interior son con organizaciones de vícti-\n'
#                               'mas del terrorismo. En el ámbito de la salud, '
#                               'las organizaciones de pacientes son las que '
#                               'ocupan un papel predominante, seguidas de las '
#                               'organizaciones humanitarias. Por último, las '
#                               'asociaciones \n'
#                               '\n'
#                               '    Junio 2024, pp.\xa0123-142\n'
#                               '134 Acceso de los grupos de interés a la arena '
#                               'gubernamental\n'
#                               'organizaciones empresariales y el resto de '
#                               'organizaciones son significativas para to-\n'
#                               'dos los casos con un intervalo de confianza del '
#                               '95\xa0%. El gráfico 2 pone de manifiesto que el '
#                               'predominio de los grupos empresariales se da '
#                               'durante todo el período, a excepción de los '
#                               'momentos en los que hay gobier-\n'
#                               'nos interinos (años 2016 y 2019) y el año de la '
#                               'moción de censura de 2018, que gana Pedro '
#                               'Sánchez. Esta concentración de la '
#                               'representación de intereses por parte de las '
#                               'organizaciones empresariales es especial-\n'
#                               'mente intensa durante el primer gobierno del '
#                               'Partido Popular (2011-2015), momento en el que '
#                               'más de la mitad de las reuniones bilaterales '
#                               'entre miembros del Gobierno y grupos de interés '
#                               'se realizan con patronales o empresas. Este '
#                               'porcentaje llega a supe-\n'
#                               'rar el 57\xa0% del total de reuniones en el año '
#                               '2014 —47 % de las reuniones con patro-\n'
#                               'nales y 8,3\xa0% con empresas—. Los miem-\n'
#                               'bros del gobierno de coalición liderado por '
#                               'Pedro Sánchez también se reúnen mayori-\n'
#                               'tariamente con las patronales y empresas, pero '
#                               'con menor intensidad —algo más del 40\xa0% de '
#                               'las reuniones entre ministros y gru-\n'
#                               'pos de interés entre 2019 y 2021—. GRÁFICO 2. '
#                               'Porcentaje de \n'
#                               '\n'
#                               '    doi:10.5477/cis/reis.186.123-142\n'
#                               'Reis. Rev.Esp.Investig.Sociol. ISSN-L: '
#                               '0210-5233. N.º 186, Abril - Junio 2024, pp.\xa0'
#                               '123-142\n'
#                               'Acceso de los grupos de interés a la arena '
#                               'gubernamental: un estudio comparativo de los '
#                               'gobiernos de Mariano Rajoy y Pedro Sánchez '
#                               '(2012-2021)\n'
#                               'Analyzing Access of Interest Groups to '
#                               'Governmental Arena: A Comparative Study of '
#                               'Mariano Rajoy and Pedro Sánchez’s '
#                               'Administrations (2012-2021)\n'
#                               'Iván Medina y Laura Chaqués-Bonafont\n'
#                               'Palabras clave\n'
#                               'Agendas\n'
#                               '• Asociaciones empresariales\n'
#                               '• Gobierno\n'
#                               '• Grupos de interés\n'
#                               '• ONG\n'
#                               '• Sindicatos\n'
#                               'Resumen\n'
#                               'Este artículo analiza el acceso de los grupos '
#                               'de interés a la arena gubernamental a partir de '
#                               'una base de datos original compuesta por 2409 '
#                               'reuniones bilaterales bajo los mandatos de '
#                               'Mariano Rajoy y Pedro Sánchez durante los años '
#                               '2012 y 2021. El análisis se construye a partir '
#                               'de los estudios de la teoría del intercambio y '
#                               'de la dinámica de la agenda y demuestra '
#                               'empíricamente que los grupos empresariales se '
#                               'reúnen con el Gobierno con más intensidad que '
#                               'cualquier otro tipo de grupo de interés, con '
#                               'diferencias significativas entre áreas '
#                               'políticas y la ideología del partido en el '
#                               'gobierno. El estudio también pone de manifiesto '
#                               'que el gobierno de coalición PSOE-UP interactúa '
#                               'más con los grupos de interés para discutir sus '
#                               'propuestas, y da más acceso a sindicatos y ONG '
#                               'que los gobiernos del Partido Popular.\n'
#                               'Key \n'
#                               '\n'
#                               '    es significativo en tanto que el acceso '
#                               'puede entenderse desde la perspectiva de la '
#                               'demanda: el equilibrio en el acceso de '
#                               'intereses económicos y so-\n'
#                               'ciales está condicionado por la agenda del '
#                               'Gobierno y la estructura del Ejecutivo.\n'
#                               'Este trabajo también argumenta que la capacidad '
#                               'de proporcionar información no es una condición '
#                               'suficiente para explicar la interacción entre '
#                               'grupos de interés y miem-\n'
#                               'bros del Gobierno. El análisis empírico de-\n'
#                               'muestra cómo, a partir de 2018, la partici-\n'
#                               'pación de los grupos de interés en la arena '
#                               'gubernamental aumenta de forma signifi-\n'
#                               'cativa como resultado de un cambio en las '
#                               'prioridades políticas de los gobiernos lidera-\n'
#                               'dos por Pedro Sánchez. Los miembros del '
#                               'gobierno socialista y de coalición se reúnen '
#                               'con más grupos de interés y de forma más '
#                               'regular que en la etapa anterior, con el fin de '
#                               'conocer sus propuestas políticas y to-\n'
#                               'mar decisiones a partir del consenso y la '
#                               'negociación política. Estos cambios ponen de '
#                               'manifiesto un cambio en la forma de en-\n'
#                               'tender el papel de los grupos de interés en el '
#                               'proceso de elaboración de las políticas '
#                               'públicas. En este sentido, uno de los cam-\n'
#                               'bios más importantes es el incremento de las '
#                               'reuniones con los sindicatos, que prác-\n'
#                               'ticamente habían desaparecido durante los '
#                               'gobiernos \n'
#                               '\n'
#                               '    mantenido con grupos de interés entre 2012 '
#                               'y 2021. Se han identificado 2409 reuniones '
#                               'bilate-\n'
#                               'rales en este periodo. Los datos se han ob-\n'
#                               'tenido a partir del análisis de la agenda dia-\n'
#                               'ria de la presidencia del Gobierno y de cada '
#                               'uno de los ministerios que se publica en el '
#                               'sitio web de La Moncloa (www.lamoncloa.\n'
#                               'gob.es). Cada una de las agendas ofrece un '
#                               'listado detallado de las actividades que rea-\n'
#                               'liza diariamente cada uno de los miembros del '
#                               'Gobierno, incluyendo las reuniones bi-\n'
#                               'laterales con grupos de interés, y los temas '
#                               'específicos de estas reuniones. Teniendo en '
#                               'cuenta el objetivo de este artículo, se han '
#                               'excluido del análisis los eventos pun-\n'
#                               'tuales como congresos, ferias o visitas a '
#                               'empresas en los que participa alguno/a de '
#                               'los/as ministros/as o el presidente del Go -\n'
#                               'bierno. La publicación de las agendas de los '
#                               'miembros del Gobierno está disponi -\n'
#                               'ble a partir de 2012, aunque solo se re-\n'
#                               'gula formalmente con la aprobación de la Ley\xa0'
#                               '19/2014, de 29 de diciembre, de Trans-\n'
#                               'parencia, Acceso a la Información Pública y '
#                               'Buen Gobierno. Esta ley obliga a los miem-\n'
#                               'bros del Gobierno a publicar sus agen-\n'
#                               'das, pero no especifica el formato en el que '
#                               'deben publicarse, ni establece nin-\n'
#                               'gún mecanismo para centralizar la infor-\n'
#                               'mación. \n'
#                               '\n'
#                               '\n'
#                               'Pregunta:Tienes el articulo Acceso de los '
#                               'grupos de interés a la arena gubernamental\n'
#                               'Respuesta:'}}

# %% [markdown]
# #### C. RAG pipeline

# %%
from haystack.components.embedders import SentenceTransformersTextEmbedder
from haystack.components.retrievers import InMemoryEmbeddingRetriever
from haystack.components.builders import PromptBuilder
from haystack.components.generators import OpenAIGenerator

rag_text_embeder = SentenceTransformersTextEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")
rag_retriever = InMemoryEmbeddingRetriever(document_store=document_store)

rag_template = """
Dada la siguiente información, responde a la pregunta

Contexto:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

Pregunta:{{ question }}
Respuesta:
"""

rag_prompt_builder = PromptBuilder(template=rag_template)
rag_generator = OpenAIGenerator(model="gpt-4o-mini-2024-07-18")

# %%
from haystack import Pipeline

rag_pipeline = Pipeline()
rag_pipeline.add_component("text_embedder", rag_text_embeder)
rag_pipeline.add_component("retriever", rag_retriever)
rag_pipeline.add_component("prompt_builder", rag_prompt_builder)
rag_pipeline.add_component("generator", rag_generator)

rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
rag_pipeline.connect("retriever", "prompt_builder.documents")
rag_pipeline.connect("prompt_builder", "generator")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7f8e7e937f50>
# 🚅 Components
#   - text_embedder: SentenceTransformersTextEmbedder
#   - retriever: InMemoryEmbeddingRetriever
#   - prompt_builder: PromptBuilder
#   - generator: OpenAIGenerator
# 🛤️ Connections
#   - text_embedder.embedding -> retriever.query_embedding (List[float])
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> generator.prompt (str)

# %%
from pprint import pprint

question = "¿Qué información tienes disponible?"

response = rag_pipeline.run({"text_embedder": {"text": question}, "prompt_builder": {"question": question}})
pprint(response)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {'generator': {'meta': [{'finish_reason': 'stop',
#                          'index': 0,
#                          'model': 'gpt-4o-mini-2024-07-18',
#                          'usage': {'completion_tokens': 526,
#                                    'completion_tokens_details': CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0),
#                                    'prompt_tokens': 3030,
#                                    'prompt_tokens_details': PromptTokensDetails(audio_tokens=0, cached_tokens=2816),
#                                    'total_tokens': 3556}}],
#                'replies': ['La información disponible en el contexto que '
#                            'proporcionaste aborda la interacción entre los '
#                            'grupos de interés, en especial económicos como '
#                            'patronales y sindicatos, y los miembros del '
#                            'Gobierno en el proceso de elaboración de políticas '
#                            'públicas. Algunos puntos clave son:\n'
#                            '\n'
#                            '1. **Dependencia de Información**: Los miembros '
#                            'del Gobierno dependen de la información y '
#                            'conocimientos que aportan diversas organizaciones '
#                            'de productores, empresas y colectivos '
#                            'profesionales para abordar problemas, definir '
#                            'propuestas y diseñar estrategias políticas.\n'
#                            '\n'
#                            '2. **Reuniones con Grupos de Interés**: Estas '
#                            'reuniones son cruciales para obtener datos, '
#                            'garantizar la calidad técnica de las propuestas '
#                            'legislativas, hacer seguimiento de políticas y '
#                            'entender las diferentes perspectivas sobre '
#                            'problemas específicos.\n'
#                            '\n'
#                            '3. **Capacidad Variada de Provisión de '
#                            'Información**: No todos los grupos de interés '
#                            'tienen la misma capacidad para proporcionar '
#                            'información relevante. Las asociaciones económicas '
#                            'suelen tener una mayor influencia en temas '
#                            'específicos, en comparación con organizaciones de '
#                            'carácter social.\n'
#                            '\n'
#                            '4. **Acceso Preferencial de Grupos Económicos**: '
#                            'Se ha observado que los grupos de interés '
#                            'económico tienen un acceso más frecuente y '
#                            'privilegiado a los miembros del Gobierno, '
#                            'especialmente en sectores como la agricultura, '
#                            'industria y mercado laboral.\n'
#                            '\n'
#                            '5. **Cambio en Dinámicas Bajo Diferentes '
#                            'Gobiernos**: Se destaca que a partir de 2018, bajo '
#                            'el gobierno de Pedro Sánchez, ha aumentado la '
#                            'interacción con grupos de interés, especialmente '
#                            'con sindicatos, lo que indica un cambio en las '
#                            'prioridades políticas y un enfoque más '
#                            'colaborativo en la toma de decisiones.\n'
#                            '\n'
#                            '6. **Categorias de Grupos de Interés**: Los grupos '
#                            'de interés se clasifican en varias categorías, '
#                            'entre ellas grupos empresariales y empresas.\n'
#                            '\n'
#                            '7. **Limitaciones en la Transparencia**: La '
#                            'información pública disponible sobre reuniones es '
#                            'limitada y varía entre el gobierno central y las '
#                            'administraciones autonómicas, lo que dificulta un '
#                            'análisis exhaustivo de las interacciones.\n'
#                            '\n'
#                            '8. **Impacto de Variables Exógenas**: Se considera '
#                            'que las variables externas, fuera del ámbito '
#                            'político, pueden influir en la eficacia política y '
#                            'el comportamiento de los grupos de interés, lo que '
#                            'podría afectar su interacción con el Gobierno.\n'
#                            '\n'
#                            '9. **Tendencias de Género en Asociaciones**: Se '
#                            'menciona la especialización por género en ciertos '
#                            'tipos de asociaciones, con predominancia masculina '
#                            'en grupos deportivos y profesionales, y femenina '
#                            'en ONG y asociaciones culturales.\n'
#                            '\n'
#                            'En resumen, la información sugiere que la '
#                            'interacción entre grupos de interés y el Gobierno '
#                            'es un aspecto fundamental en la formulación de '
#                            'políticas, con diferencias notables en el acceso y '
#                            'la capacidad de influencia según la naturaleza del '
#                            'grupo de interés.']}}
