# %% [markdown]
# ### [How to chain runnables](https://python.langchain.com/docs/how_to/sequence/)

# %%
import getpass
import os

if "LANGCHAIN_API_KEY" not in os.environ:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# #### A. Model

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")

chain = prompt | model | StrOutputParser()

# chain.invoke({"topic": "programacion"})
chunks = []
for chunk in chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |¡|Claro|!| Aquí| tienes| uno|:
#
# |¿Por| qué| los| program|adores| pref|ieren| el| café| oscuro|?
#
# |¡|Porque| les| gusta| tener| menos| bugs|!| ☕|🐛|
#
# |Espero| que| te| haya| sac|ado| una| sonrisa|.| Si| quieres| otro|,| ¡|d|ím|elo|!||

# %% [markdown]
# #### B. Coercion

# %%
from langchain_core.output_parsers import StrOutputParser

analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}")

composed_chain = {"joke": chain} | analysis_prompt | model | StrOutputParser()

# composed_chain.invoke({"topic": "programacion"})
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| un| par| de| conceptos| que| son| comunes| en| el| ámbito| de| la| programación| y| la| cultura| de| los| program|adores|.| Vamos| a| des|gl|os|arlo|:
#
# |1|.| **|C|afé| oscuro|**|:| La| referencia| al| café| oscuro| su|gi|ere| que| los| program|adores|,| que| a| menudo| se| as|oc|ian| con| largas| horas| de| trabajo|,| pref|ieren| una| bebida| que| les| mant|enga| alert|as| y| despi|ertos|.| El| café| es| una| bebida| popular| en| la| comunidad| de| program|adores|.
#
# |2|.| **|L|uz| y| bugs|**|:| La| parte| más| ingen|iosa| del| ch|iste| es| la| al|usión| a| los| "|bugs|"| (|erro|res| o| fall|os| en| el| software|)| y| cómo| la| luz| atra|e| a| los| insect|os|.| En| la| programación|,| "|bugs|"| se| refiere| a| problemas| en| el| código| que| deben| solucion|arse|.| La| idea| de| que| "|la| luz| atra|e| a| los| bugs|"| crea| un| juego| de| palabras| que| conecta| la| idea| literal| de| los| insect|os| siendo| atra|ídos| por| la| luz| y| los| errores| en| el| código| que| parecen| aparecer| cuando| se| "|il|umin|an|"| o| se| revis|an| ciertas| áreas| del| programa|.
#
# |3|.| **|Hum|or| técnico|**|:| El| ch|iste| es| un| ejemplo| de| humor| técnico| que| solo| reson|ará| completamente| con| aquellos| que| tienen| algún| conocimiento| de| programación|.| Esto| lo| convierte| en| un| ch|iste| de| "|in|-group|",| donde| solo| ciertos| miembros| de| una| comunidad| lo| encuentran| grac|ioso|.
#
# |4|.| **|E|fect|o| sorpresa|**|:| La| estructura| del| ch|iste| lleva| a| una| conclusión| inesper|ada|,| ya| que| el| oy|ente| podría| anticip|ar| una| respuesta| sobre| el| café| oscuro| que| no| esté| relacionada| con| bugs|.| La| revel|ación| final| es| lo| que| genera| la| r|isa|.
#
# |En| resumen|,| el| ch|iste| combina| el| amor| por| el| café| en| la| cultura| de| los| program|adores| con| un| juego| de| palabras| sobre| bugs|,| utilizando| una| metá|fora| visual| que| hace| que| sea| divertido| para| quienes| están| familiar|izados| con| el| mundo| de| la| programación|.||

# %% [markdown]
# #### C. Test

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Paso 1: Crear el primer chain para generar un chiste
joke_prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")
joke_chain = joke_prompt | model | StrOutputParser()

# Paso 2: Crear el segundo chain para analizar el chiste
analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}, finaliza con 'EN RESUMEN: '")
composed_chain = {"joke": joke_chain} | analysis_prompt | model | StrOutputParser()

# Paso 3: Realizar el streaming del composed_chain
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| el| vocab|ulario| técnico| de| la| programación| y| la| cultura| del| café|.| La| primera| parte| establece| una| prem|isa| simple|:| los| program|adores| pref|ieren| el| café| oscuro|.| Esta| elección| se| presenta| como| algo| que| podría| ser| trivial|,| pero| la| razón| que| se| ofrece| es| un| juego| de| palabras| ingen|ioso|.
#
# |La| parte| clave| del| ch|iste| es| la| referencia| a| "|erro|res| de| tipo|".| En| programación|,| un| "|error| de| tipo|"| ocurre| cuando| se| intenta| realizar| una| operación| entre| datos| de| tipos| incompat|ibles|.| Por| otro| lado|,| "|c|afé| con| leche|"| es| una| bebida| que| mezcla| café| (|que| se| puede| asoci|ar| con| un| tipo| oscuro|)| y| leche| (|que| aporta| otro| tipo|,| más| claro|).| La| b|roma| rad|ica| en| la| conf|usión| de| tipos|:| mez|clar| café| con| leche|,| en| un| sentido| humor|ístico|,| se| compara| con| mez|clar| tipos| de| datos| en| programación|,| lo| que| puede| causar| problemas|.
#
# |En| resumen|,| el| ch|iste| utiliza| el| doble| sentido| y| el| conocimiento| de| programación| para| crear| humor|,| logr|ando| conectar| la| cultura| del| café| con| el| mundo| de| la| programación| de| manera| creat|iva|.
#
# |EN| RES|UM|EN|:| El| ch|iste| es| un| juego| de| palabras| que| combina| la| prefer|encia| de| los| program|adores| por| el| café| oscuro| y| los| errores| de| tipo| en| programación|,| creando| un| humor| ingen|ioso| a| partir| de| conceptos| técnicos|.||

# %%
events = []
async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    events.append(event)

event_types = {event["event"] for event in events}
print("Unique event types:", event_types)
# Out:
# Unique event types: {'on_chat_model_start', 'on_parser_stream', 'on_chain_end', 'on_chat_model_stream', 'on_chain_start', 'on_parser_start', 'on_prompt_start', 'on_chain_stream', 'on_prompt_end', 'on_parser_end', 'on_chat_model_end'}

# %%
async for event in model.astream_events("programacion", version="v2"):
    if event["event"] == "on_chat_model_start":
        print("Stream started...", flush=True)
    elif event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"])
# Out:
# Stream started...
# content='' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='¡' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='Claro' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='!' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' La' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' programación' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' es' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' el' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' proceso' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' de' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' crear' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' un' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' conjunto' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' de' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' instrucciones' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' para' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' que' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' una' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' computadora' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' real' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='ice' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' tareas' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' específicas' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='.' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' Puedes' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' program' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='ar' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' en' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' varios' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' leng' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='u' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='ajes' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=',' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' como' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' Python' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=',' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' Java' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=',' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' C' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='++,' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' Java' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='Script' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=',' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' entre' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' otros' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='.' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' ¿' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='T' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='ienes' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' alguna' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' pregunta' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' específica' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' sobre' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' programación' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' o' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' algún' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' tema' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' en' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' particular' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' que' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' te' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' gustaría' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content=' explorar' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='?' additional_kwargs={} response_metadata={} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_d02d531b47'} id='run-943bee8c-bea7-4961-9af5-de3f7f1860f0'

# %%
events = [
    event
    async for event in composed_chain.astream_events(
        {"topic": "programacion"},
        version="v2",
    )
]

# %%
events
# Out:
# [{'event': 'on_chain_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'RunnableSequence',
#   'tags': [],
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'metadata': {},
#   'parent_ids': []},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'metadata': {},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'metadata': {},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_prompt_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'run_id': '1005a76d-00f0-4ee5-96a0-1d93e4fb5744',
#   'metadata': {},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_prompt_end',
#   'data': {'output': ChatPromptValue(messages=[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]),
#    'input': {'topic': 'programacion'}},
#   'run_id': '1005a76d-00f0-4ee5-96a0-1d93e4fb5744',
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chat_model_start',
#   'data': {'input': {'messages': [[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]]}},
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_start',
#   'data': {},
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'metadata': {},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ''}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¡', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¡'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Claro', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Claro'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Claro'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Claro'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '!'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '!'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '!'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Aquí', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Aquí'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Aquí'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Aquí'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' tienes', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' tienes'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' tienes'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' tienes'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' uno', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' uno'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' uno'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' uno'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ':\n\n'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ':\n\n'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ':\n\n'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¿Por', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¿Por'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¿Por'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¿Por'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' qué', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' qué'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' los', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' los'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' program', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' program'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='adores', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'adores'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' pref', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' pref'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' pref'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' pref'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='ieren', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'ieren'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'ieren'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'ieren'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' el', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' el'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' el'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' el'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' café', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' café'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' café'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' café'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='?\n\n', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '?\n\n'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '?\n\n'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '?\n\n'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Porque', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Porque'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Porque'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Porque'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' el', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' el'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' el'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' el'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' té', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' té'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' té'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' té'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' tiene', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' tiene'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' tiene'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' tiene'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' muchos', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' muchos'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' muchos'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' muchos'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' errores', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' errores'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' errores'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' errores'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '.'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ☕', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' ☕'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' ☕'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' ☕'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='️', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '️'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '️'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '️'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='💻', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '💻'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '💻'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '💻'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '\n\n'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '\n\n'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '\n\n'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¡', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¡'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Espero', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Espero'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Espero'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d']},
#  {'event': 'on_chain_stream',
#   'run_id': '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Espero'}},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' que', additional_kwargs={}, response_metadata={}, id='run-cd3194c7-0053-4184-ad6d-f8e43c6fc461')},
#   'run_id': 'cd3194c7-0053-4184-ad6d-f8e43c6fc461',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_parser_stream',
#   'run_id': 'fa0e11a3-1210-4998-9169-832d1f043a6d',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#    '147256d9-4cef-4d7e-ace3-8e9e7db7b41d',
#    'a21b9aee-0e04-42ca-900e-5bb1a474c55e']},
#  {'event': 'on_chain_stream',
#   'run_id': 'a21b9aee-0e04-42ca-900e-5bb1a474c55e',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' que'},
# ...
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' está'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' está'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' "'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' "'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='ll', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'll'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'll'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='eno', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'eno'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'eno'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' de', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' errores', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' errores'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' errores'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='",', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '",'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '",'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' lo', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' lo'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' lo'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' que', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' provoca', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' provoca'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' provoca'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' una', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' una'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' una'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' sonrisa', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' sonrisa'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' sonrisa'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' al', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' al'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' al'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' jugar', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' jugar'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' jugar'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' con', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' con'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' con'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' la', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' la'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' la'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' termin', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' termin'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' termin'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='ología', additional_kwargs={}, response_metadata={}, id='run-5d0101e9-3d40-4534-9bdf-c5d9f6a462b2')},
#   'run_id': '5d0101e9-3d40-4534-9bdf-c5d9f6a462b2',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_parser_stream',
#   'run_id': '75c7ecb6-f0be-46bb-b77b-3732c2c527a7',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'ología'},
#   'parent_ids': ['5ab86511-1ee3-4b7c-9a2e-958b844039d4']},
#  {'event': 'on_chain_stream',
#   'run_id': '5ab86511-1ee3-4b7c-9a2e-958b844039d4',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'ología'},
#   'parent_ids': []},
#  ...]

# %%
num_events = 0

async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    kind = event["event"]
    
    if kind == "on_chat_model_stream":
        chunk = event["data"]["chunk"].content
        print(f"Chat model chunk: {repr(chunk)}", flush=True)

    elif kind == "on_parser_stream":
        chunk = event["data"]["chunk"]
        print(f"Parser chunk: {chunk}", flush=True)

    elif kind == "on_chain_stream":
        chunk = event["data"].get("chunk", None)
        if isinstance(chunk, dict):
            for key, value in chunk.items():
                print(f"Chain {key} chunk: {repr(value)}", flush=True)
        else:
            print(f"Chain chunk: {repr(chunk)}", flush=True)

    num_events += 1

    if num_events > 30:  # Truncate output if too many events
        print("...", flush=True)
        break
# Out:
# Chat model chunk: ''
# Parser chunk:
# Chain chunk: ''
# Chain joke chunk: ''
# Chat model chunk: '¡'
# Parser chunk: ¡
# Chain chunk: '¡'
# Chain joke chunk: '¡'
# Chat model chunk: 'Claro'
# Parser chunk: Claro
# Chain chunk: 'Claro'
# Chain joke chunk: 'Claro'
# Chat model chunk: '!'
# Parser chunk: !
# Chain chunk: '!'
# Chain joke chunk: '!'
# Chat model chunk: ' Aquí'
# Parser chunk:  Aquí
# Chain chunk: ' Aquí'
# Chain joke chunk: ' Aquí'
# Chat model chunk: ' tienes'
# Parser chunk:  tienes
# Chain chunk: ' tienes'
# Chain joke chunk: ' tienes'
# ...

# %% [markdown]
# #### D. Metodo pipe

# %%
from langchain_core.runnables import RunnableParallel

composed_chain_with_pipe = (
    RunnableParallel({"joke": chain})
    .pipe(analysis_prompt)
    .pipe(model)
    .pipe(StrOutputParser())
)

composed_chain_with_pipe.invoke({"topic": "battlestar galactica"})
# Out:
# 'Este chiste juega con el concepto de los Cylons en "Battlestar Galactica", una serie de ciencia ficción donde los Cylons son máquinas inteligentes que pueden imitar a los humanos. La clave del chiste radica en la palabra "trucos", que puede referirse tanto a las estrategias que se utilizan en el juego de cartas como a la idea de que los Cylons son muy buenos en el engaño y la manipulación.\n\nLa broma se basa en la ambigüedad de la palabra "trucos". En un sentido, se refiere a las jugadas que un jugador puede usar en un juego de cartas, pero también insinúa que los Cylons, al ser seres artificiales, no pueden ocultar sus verdaderas intenciones o habilidades, lo que hace que se "descubran" fácilmente en el contexto del juego.\n\nEl humor también proviene del contraste entre la idea de un juego de cartas, que suele ser un pasatiempo social y divertido, y la seriedad y la tensión que rodean la relación entre humanos y Cylons en la serie. Este tipo de chiste puede ser especialmente apreciado por los fanáticos de "Battlestar Galactica", ya que incluye un elemento de conocimiento sobre la trama y los personajes.\n\nEn resumen, el chiste utiliza un juego de palabras y referencias al contexto de la serie para generar humor, lo que puede resultar en una sonrisa para quienes están familiarizados con el material.'

# %%
composed_chain_with_pipe = RunnableParallel({"joke": chain}).pipe(
    analysis_prompt, model, StrOutputParser()
)

chunks = []
for chunk in composed_chain_with_pipe.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| dos| conceptos| que| son| familiares| tanto| para| program|adores| como| para| quienes| disfr|utan| del| café|.|
#
# |1|.| **|Referencia| al| café| oscuro|**|:| El| "|c|afé| oscuro|"| se| refiere| a| un| tipo| de| café| que| se| tu|esta| más| tiempo|,| lo| que| resulta| en| un| sabor| más| fuerte| y| intenso|.| Es| un| juego| de| palabras| que| ev|oca| la| prefer|encia| de| muchos| program|adores| por| ese| tipo| de| café|.
#
# |2|.| **|Juego| de| palabras| con| "|c|ódigo| sin| errores|"|**|:| Aquí| está| la| clave| del| ch|iste|.| En| programación|,| "|c|ódigo| sin| errores|"| significa| que| el| código| no| tiene| bugs| o| fall|os|,| lo| cual| es| un| objetivo| primordial| para| los| program|adores|.| Sin| embargo|,| el| ch|iste| su|gi|ere| que| al| igual| que| pref|ieren| su| café| oscuro|,| también| desean| que| su| código| esté| libre| de| errores|.
#
# |La| combinación| de| estos| dos| elementos| crea| una| conexión| humor|ística| que| es| especialmente| apreci|ada| por| aquellos| en| el| campo| de| la| tecnología|.| Además|,| el| uso| de| emojis| (|☕|💻|)| añade| un| toque| visual| que| ref|uer|za| el| tema| del| ch|iste|.
#
# |En| resumen|,| el| ch|iste| es| efectivo| porque| juega| con| la| cultura| del| café| y| la| programación|,| haciendo| que| sea| relevante| y| divertido| para| su| audiencia| objetivo|.| ¡|Y| claro|,| siempre| es| bueno| compartir| una| sonrisa|!| Si| te| interesa| otro| ch|iste|,| ¡|estar|é| encant|ado| de| ayudarte|!||
