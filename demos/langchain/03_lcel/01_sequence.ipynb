# %% [markdown]
# ### [How to chain runnables](https://python.langchain.com/docs/how_to/sequence/)

# %%
import getpass
import os

if "LANGCHAIN_API_KEY" not in os.environ:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# #### A. Model

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")

chain = prompt | model | StrOutputParser()

# chain.invoke({"topic": "programacion"})
chunks = []
for chunk in chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |¡|Claro|!| Aquí| tienes| uno|:
#
# |¿Por| qué| los| program|adores| pref|ieren| el| café| oscuro|?
#
# |¡|Porque| les| gusta| tener| menos| bugs|!| ☕|🐛|
#
# |Espero| que| te| haya| sac|ado| una| sonrisa|.| Si| quieres| otro|,| ¡|d|ím|elo|!||

# %% [markdown]
# #### B. Coercion

# %%
from langchain_core.output_parsers import StrOutputParser

analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}")

composed_chain = {"joke": chain} | analysis_prompt | model | StrOutputParser()

# composed_chain.invoke({"topic": "programacion"})
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| un| par| de| conceptos| que| son| comunes| en| el| ámbito| de| la| programación| y| la| cultura| de| los| program|adores|.| Vamos| a| des|gl|os|arlo|:
#
# |1|.| **|C|afé| oscuro|**|:| La| referencia| al| café| oscuro| su|gi|ere| que| los| program|adores|,| que| a| menudo| se| as|oc|ian| con| largas| horas| de| trabajo|,| pref|ieren| una| bebida| que| les| mant|enga| alert|as| y| despi|ertos|.| El| café| es| una| bebida| popular| en| la| comunidad| de| program|adores|.
#
# |2|.| **|L|uz| y| bugs|**|:| La| parte| más| ingen|iosa| del| ch|iste| es| la| al|usión| a| los| "|bugs|"| (|erro|res| o| fall|os| en| el| software|)| y| cómo| la| luz| atra|e| a| los| insect|os|.| En| la| programación|,| "|bugs|"| se| refiere| a| problemas| en| el| código| que| deben| solucion|arse|.| La| idea| de| que| "|la| luz| atra|e| a| los| bugs|"| crea| un| juego| de| palabras| que| conecta| la| idea| literal| de| los| insect|os| siendo| atra|ídos| por| la| luz| y| los| errores| en| el| código| que| parecen| aparecer| cuando| se| "|il|umin|an|"| o| se| revis|an| ciertas| áreas| del| programa|.
#
# |3|.| **|Hum|or| técnico|**|:| El| ch|iste| es| un| ejemplo| de| humor| técnico| que| solo| reson|ará| completamente| con| aquellos| que| tienen| algún| conocimiento| de| programación|.| Esto| lo| convierte| en| un| ch|iste| de| "|in|-group|",| donde| solo| ciertos| miembros| de| una| comunidad| lo| encuentran| grac|ioso|.
#
# |4|.| **|E|fect|o| sorpresa|**|:| La| estructura| del| ch|iste| lleva| a| una| conclusión| inesper|ada|,| ya| que| el| oy|ente| podría| anticip|ar| una| respuesta| sobre| el| café| oscuro| que| no| esté| relacionada| con| bugs|.| La| revel|ación| final| es| lo| que| genera| la| r|isa|.
#
# |En| resumen|,| el| ch|iste| combina| el| amor| por| el| café| en| la| cultura| de| los| program|adores| con| un| juego| de| palabras| sobre| bugs|,| utilizando| una| metá|fora| visual| que| hace| que| sea| divertido| para| quienes| están| familiar|izados| con| el| mundo| de| la| programación|.||

# %% [markdown]
# #### C. Test

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Paso 1: Crear el primer chain para generar un chiste
joke_prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")
joke_chain = joke_prompt | model | StrOutputParser()

# Paso 2: Crear el segundo chain para analizar el chiste
analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}")
composed_chain = {"joke": joke_chain} | analysis_prompt | model | StrOutputParser()

# Paso 3: Realizar el streaming del composed_chain
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| dos| conceptos| que| son| comunes| en| el| ámbito| de| la| programación| y| la| cultura| de| los| program|adores|.|
#
# |1|.| **|C|afé| oscuro|**|:| Esta| parte| del| ch|iste| hace| referencia| a| la| prefer|encia| por| el| café| más| fuerte| o| con| un| sabor| más| intenso|,| que| es| un| est|ere|otipo| asociado| a| muchos| program|adores| que| suelen| consumir| café| para| mantenerse| despi|ertos| y| concentr|ados| durante| largas| horas| de| trabajo|.
#
# |2|.| **|"|Byte|"|**|:| Aquí| se| hace| un| juego| de| palabras|.| En| el| ámbito| de| la| informática|,| un| byte| es| una| unidad| de| datos|.| Sin| embargo|,| la| palabra| "|byte|"| su|ena| similar| a| "|bite|"| (|m|ord|isco| en| inglés|),| lo| que| añade| un| doble| sentido| al| ch|iste|.| La| b|roma| su|gi|ere| que| los| program|adores| pref|ieren| el| café| oscuro| porque| "|t|ienen| un| buen| byte|",| insinu|ando| que| disfr|utan| tanto| del| café| como| de| la| programación|.
#
# |El| humor| prov|iene| del| uso| de| la| jer|ga| técnica| y| el| juego| de| palabras|,| lo| que| lo| hace| especialmente| atractivo| para| aquellos| familiar|izados| con| la| programación|.| Además|,| el| ch|iste| es| ligero| y| amig|able|,| lo| que| contrib|uye| a| crear| un| ambiente| de| camar|adería| entre| los| program|adores|.|
#
# |En| resumen|,| el| ch|iste| es| un| buen| ejemplo| de| humor| geek| que| combina| elementos| de| la| cultura| de| la| programación| con| un| toque| de| ingen|io|.| ¡|Y| definitivamente| es| una| buena| manera| de| sac|arle| una| sonrisa| a| alguien| del| mundo| tech|!| Si| estás| interesado| en| más| ch|istes| o| juegos| de| palabras|,| ¡|estar|é| encant|ado| de| ayudarte|!||

# %%
events = []
async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    events.append(event)

event_types = {event["event"] for event in events}
print("Unique event types:", event_types)
# Out:
# Unique event types: {'on_chat_model_start', 'on_parser_stream', 'on_chain_end', 'on_chat_model_stream', 'on_chain_start', 'on_parser_start', 'on_prompt_start', 'on_chain_stream', 'on_prompt_end', 'on_parser_end', 'on_chat_model_end'}

# %%
events = [
    event
    async for event in composed_chain.astream_events(
        {"topic": "programacion"},
        version="v2",
    )
]

# %%
events
# Out:
# [{'event': 'on_chain_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'RunnableSequence',
#   'tags': [],
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'metadata': {},
#   'parent_ids': []},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'metadata': {},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'metadata': {},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_prompt_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'run_id': '79d52ae9-c969-4f03-8311-ce9508d49949',
#   'metadata': {},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_prompt_end',
#   'data': {'output': ChatPromptValue(messages=[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]),
#    'input': {'topic': 'programacion'}},
#   'run_id': '79d52ae9-c969-4f03-8311-ce9508d49949',
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chat_model_start',
#   'data': {'input': {'messages': [[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]]}},
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_start',
#   'data': {},
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'metadata': {},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ''}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¡', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¡'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Claro', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Claro'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Claro'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Claro'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '!'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '!'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '!'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Aquí', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Aquí'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Aquí'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Aquí'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' va', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' va'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' va'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' va'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' uno', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' uno'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' uno'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' uno'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ':\n\n'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ':\n\n'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ':\n\n'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¿Por', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¿Por'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¿Por'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¿Por'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' qué', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' qué'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' los', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' los'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' program', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' program'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='adores', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'adores'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' conf', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' conf'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' conf'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' conf'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='unden', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'unden'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'unden'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'unden'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Halloween', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Halloween'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Halloween'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Halloween'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' y', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' y'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' y'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' y'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Navidad', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Navidad'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Navidad'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Navidad'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='?\n\n', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '?\n\n'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '?\n\n'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '?\n\n'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Porque', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Porque'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Porque'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Porque'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Oct', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Oct'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Oct'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Oct'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' '}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='31', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '31'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '31'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '31'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' es', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' es'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' es'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' es'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' igual', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' igual'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' igual'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' igual'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' a'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' a'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' a'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Dec', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Dec'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Dec'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Dec'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' '}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='25', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '25'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '25'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '25'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '.'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' \n\n', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' \n\n'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' \n\n'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4']},
#  {'event': 'on_chain_stream',
#   'run_id': '69890a82-fd06-4152-a434-cfb3e14be6a4',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' \n\n'}},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='(', additional_kwargs={}, response_metadata={}, id='run-45420255-0a0d-4c5a-a899-1036c97ec2da')},
#   'run_id': '45420255-0a0d-4c5a-a899-1036c97ec2da',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_parser_stream',
#   'run_id': '0486a4a1-2ad4-44d1-ae17-be22a8d6da01',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '('},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319',
#    '69890a82-fd06-4152-a434-cfb3e14be6a4',
#    '701f6408-72e3-43c3-9434-0db1381d2284']},
#  {'event': 'on_chain_stream',
#   'run_id': '701f6408-72e3-43c3-9434-0db1381d2284',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '('},
# ...
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '0'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '0'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ','},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ','},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' que', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' es', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' es'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' es'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' igual', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' igual'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' igual'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' a'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' a'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='25', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '25'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '25'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' en', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' en'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' en'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' decimal', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' decimal'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' decimal'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' ('},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' ('},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '3'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '3'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '*'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '*'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='8', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '8'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '8'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' +', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' +'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' +'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '1'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_chain_stream',
#   'run_id': 'b3b4240d-1c32-4a56-97bb-feea0a41d319',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '1'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='run-681f27df-b6aa-4435-ae06-77217868684a')},
#   'run_id': '681f27df-b6aa-4435-ae06-77217868684a',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  {'event': 'on_parser_stream',
#   'run_id': 'ef9e8acc-fb9b-4927-91f7-9c8ad3a718ab',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '*'},
#   'parent_ids': ['b3b4240d-1c32-4a56-97bb-feea0a41d319']},
#  ...]

# %%
num_events = 0

async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    kind = event["event"]
    
    if kind == "on_chat_model_stream":
        chunk = event["data"]["chunk"].content
        print(f"Chat model chunk: {repr(chunk)}", flush=True)

    elif kind == "on_parser_stream":
        chunk = event["data"]["chunk"]
        print(f"Parser chunk: {chunk}", flush=True)

    elif kind == "on_chain_stream":
        chunk = event["data"].get("chunk", None)
        if isinstance(chunk, dict):
            for key, value in chunk.items():
                print(f"Chain {key} chunk: {repr(value)}", flush=True)
        else:
            print(f"Chain chunk: {repr(chunk)}", flush=True)

    num_events += 1

    if num_events > 30:  # Truncate output if too many events
        print("...", flush=True)
        break
# Out:
# Chat model chunk: ''
# Parser chunk:
# Chain chunk: ''
# Chain joke chunk: ''
# Chat model chunk: '¡'
# Parser chunk: ¡
# Chain chunk: '¡'
# Chain joke chunk: '¡'
# Chat model chunk: 'Claro'
# Parser chunk: Claro
# Chain chunk: 'Claro'
# Chain joke chunk: 'Claro'
# Chat model chunk: '!'
# Parser chunk: !
# Chain chunk: '!'
# Chain joke chunk: '!'
# Chat model chunk: ' Aquí'
# Parser chunk:  Aquí
# Chain chunk: ' Aquí'
# Chain joke chunk: ' Aquí'
# Chat model chunk: ' tienes'
# Parser chunk:  tienes
# Chain chunk: ' tienes'
# Chain joke chunk: ' tienes'
# ...

# %% [markdown]
# #### D. Metodo pipe

# %%
from langchain_core.runnables import RunnableParallel

composed_chain_with_pipe = (
    RunnableParallel({"joke": chain})
    .pipe(analysis_prompt)
    .pipe(model)
    .pipe(StrOutputParser())
)

composed_chain_with_pipe.invoke({"topic": "battlestar galactica"})
# Out:
# 'Este chiste juega con el concepto de los Cylons en "Battlestar Galactica", una serie de ciencia ficción donde los Cylons son máquinas inteligentes que pueden imitar a los humanos. La clave del chiste radica en la palabra "trucos", que puede referirse tanto a las estrategias que se utilizan en el juego de cartas como a la idea de que los Cylons son muy buenos en el engaño y la manipulación.\n\nLa broma se basa en la ambigüedad de la palabra "trucos". En un sentido, se refiere a las jugadas que un jugador puede usar en un juego de cartas, pero también insinúa que los Cylons, al ser seres artificiales, no pueden ocultar sus verdaderas intenciones o habilidades, lo que hace que se "descubran" fácilmente en el contexto del juego.\n\nEl humor también proviene del contraste entre la idea de un juego de cartas, que suele ser un pasatiempo social y divertido, y la seriedad y la tensión que rodean la relación entre humanos y Cylons en la serie. Este tipo de chiste puede ser especialmente apreciado por los fanáticos de "Battlestar Galactica", ya que incluye un elemento de conocimiento sobre la trama y los personajes.\n\nEn resumen, el chiste utiliza un juego de palabras y referencias al contexto de la serie para generar humor, lo que puede resultar en una sonrisa para quienes están familiarizados con el material.'

# %%
composed_chain_with_pipe = RunnableParallel({"joke": chain}).pipe(
    analysis_prompt, model, StrOutputParser()
)

chunks = []
for chunk in composed_chain_with_pipe.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| dos| conceptos| que| son| familiares| tanto| para| program|adores| como| para| quienes| disfr|utan| del| café|.|
#
# |1|.| **|Referencia| al| café| oscuro|**|:| El| "|c|afé| oscuro|"| se| refiere| a| un| tipo| de| café| que| se| tu|esta| más| tiempo|,| lo| que| resulta| en| un| sabor| más| fuerte| y| intenso|.| Es| un| juego| de| palabras| que| ev|oca| la| prefer|encia| de| muchos| program|adores| por| ese| tipo| de| café|.
#
# |2|.| **|Juego| de| palabras| con| "|c|ódigo| sin| errores|"|**|:| Aquí| está| la| clave| del| ch|iste|.| En| programación|,| "|c|ódigo| sin| errores|"| significa| que| el| código| no| tiene| bugs| o| fall|os|,| lo| cual| es| un| objetivo| primordial| para| los| program|adores|.| Sin| embargo|,| el| ch|iste| su|gi|ere| que| al| igual| que| pref|ieren| su| café| oscuro|,| también| desean| que| su| código| esté| libre| de| errores|.
#
# |La| combinación| de| estos| dos| elementos| crea| una| conexión| humor|ística| que| es| especialmente| apreci|ada| por| aquellos| en| el| campo| de| la| tecnología|.| Además|,| el| uso| de| emojis| (|☕|💻|)| añade| un| toque| visual| que| ref|uer|za| el| tema| del| ch|iste|.
#
# |En| resumen|,| el| ch|iste| es| efectivo| porque| juega| con| la| cultura| del| café| y| la| programación|,| haciendo| que| sea| relevante| y| divertido| para| su| audiencia| objetivo|.| ¡|Y| claro|,| siempre| es| bueno| compartir| una| sonrisa|!| Si| te| interesa| otro| ch|iste|,| ¡|estar|é| encant|ado| de| ayudarte|!||
