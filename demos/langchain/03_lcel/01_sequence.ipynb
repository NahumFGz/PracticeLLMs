# %% [markdown]
# ### [How to chain runnables](https://python.langchain.com/docs/how_to/sequence/)

# %%
import getpass
import os

if "LANGCHAIN_API_KEY" not in os.environ:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# #### A. Model

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")

chain = prompt | model | StrOutputParser()

# chain.invoke({"topic": "programacion"})
chunks = []
for chunk in chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |¡|Claro|!| Aquí| tienes| uno|:
#
# |¿Por| qué| los| program|adores| conf|unden| Halloween| y| Navidad|?
#
# |¡|Porque| OCT| |31| es| igual| a| DEC| |25|!|
#
# |(|Exp|lic|ación|:| en| programación|,| "|O|CT|"| se| refiere| a| la| base| oct|al| (|base| |8|)| y| "|DEC|"| a| la| base| decimal| (|base| |10|).| En| base| oct|al|,| |31| es| igual| a| |3|*|8| +| |1| =| |25| en| decimal|).||

# %% [markdown]
# #### B. Coercion

# %%
from langchain_core.output_parsers import StrOutputParser

analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}")

composed_chain = {"joke": chain} | analysis_prompt | model | StrOutputParser()

# composed_chain.invoke({"topic": "programacion"})
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |¡|Claro|!| Vamos| a| analizar| el| ch|iste|:
#
# |1|.| **|Context|o| y| temática|**|:| El| ch|iste| se| sit|úa| en| el| mundo| de| la| programación|,| un| campo| muy| específico| que| generalmente| es| conocido| por| su| jer|ga| técnica| y| sus| propios| ch|istes| internos|.| El| humor| aquí| se| basa| en| la| cultura| de| los| program|adores| y| su| relación| con| el| café|.
#
# |2|.| **|Juego| de| palabras|**|:| La| b|roma| se| basa| en| un| juego| de| palabras| entre| "|c|afé| oscuro|"| y| "|c|ódigo| claro|".| Por| un| lado|,| "|c|afé| oscuro|"| se| refiere| a| un| tipo| de| café|,| mientras| que| "|c|ódigo| claro|"| se| refiere| a| un| código| que| es| fácil| de| leer| y| entender|.| Este| juego| de| palabras| crea| una| conexión| humor|ística| entre| dos| conceptos| que|,| a| primera| vista|,| parecen| no| estar| relacionados|.
#
# |3|.| **|La| resolución|**|:| La| segunda| parte| del| ch|iste|,| "|no| tiene| bugs|",| juega| con| la| idea| de| que| un| "|c|ódigo| claro|"| es| menos| prop|enso| a| tener| errores| (|bugs|).| Este| es| un| concepto| común| en| programación|:| un| código| bien| estruct|urado| y| fácil| de| entender| ti|ende| a| tener| menos| problemas|.| La| iron|ía| aquí| es| que|,| aunque| el| café| oscuro| es| prefer|ido|,| el| verdadero| significado| de| "|c|ódigo| claro|"| implica| que| no| debería| haber| errores|,| lo| cual| es| muy| dese|able| para| un| program|ador|.
#
# |4|.| **|Element|os| visual|es|**|:| Los| emojis| ☕|💻| añ|aden| un| toque| visual| que| complement|a| el| ch|iste| y| lo| hace| más| atractivo|.| El| café| (|☕|)| representa| la| bebida| favorita| de| muchos| program|adores|,| y| el| ordenador| (|💻|)| simbol|iza| su| herramienta| de| trabajo|.
#
# |5|.| **|Re|acción| esper|ada|**|:| El| objetivo| del| ch|iste| es| provocar| una| sonrisa| o| r|isa| entre| quienes| compr|enden| la| jer|ga| de| la| programación|.| Es| un| tipo| de| humor| que| reson|ará| más| con| aquellos| familiar|izados| con| el| entorno| de| los| program|adores|.
#
# |En| resumen|,| es| un| ch|iste| ingen|ioso| que| utiliza| el| lenguaje| y| la| cultura| de| la| programación| para| crear| un| juego| de| palabras| que| resulta| divertido|,| especialmente| para| su| audiencia|.| ¡|Gracias| por| compartir|lo|!| Si| quieres| escuchar| otro|,| ¡|d|ím|elo|!||

# %% [markdown]
# #### C. Test

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Paso 1: Crear el primer chain para generar un chiste
joke_prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")
joke_chain = joke_prompt | model | StrOutputParser()

# Paso 2: Crear el segundo chain para analizar el chiste
analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}")
composed_chain = {"joke": joke_chain} | analysis_prompt | model | StrOutputParser()

# Paso 3: Realizar el streaming del composed_chain
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| se| bas|a| en| un| juego| de| palabras| y| conoc|imientos| de| sistemas| de| numer|ación| en| program|ación|.| En| program|ación|,| a| men|udo| se| us|an| diferentes| bases| de| numer|ación|,| no| solo| la| base| |10|,| que| us|amos| en| la| vida| cot|id|iana|.| La| base| |16| se| llama| hexadecimal| (|HE|X|),| y| la| base| |8| se| llama| oct|al| (|O|CT|).
#
# |En| el| ch|iste|,| "|31| OCT|"| es| interpret|ado| como| un| número| en| base| |8| (|oct|al|),| mientras| que| "|25| DEC|"| es| interpret|ado| como| un| número| en| base| |10| (|decimal|,| que| es| el| sistema| que| us|amos| normal|mente|).|
#
# |El| número| |31| en| base| oct|al| es| igual| al| número| |25| en| base| decimal|.| Ent|onces|,| aunque| pare|z|ca| que| estamos| compar|ando| fe|chas| (|31| de| oct|ubre|,| que| es| Halloween|,| y| |25| de| dici|embre|,| que| es| Nav|idad|),| en| realidad| estamos| compar|ando| números| en| diferentes| bases| de| numer|ación|.|
#
# |Por| lo| tanto|,| el| ch|iste| es| una| espec|ie| de| mal|ent|end|ido| int|enc|ional|,| en| el| que| los| program|adores| "|mez|cl|an|"| Halloween| y| Nav|idad| debido| a| su| conoc|imiento| de| los| sistemas| de| numer|ación|.| Este| es| un| ch|iste| que| probable|mente| solo| será| comprend|ido| y| ap|rec|iado| por| aquel|los| que| tienen| conoc|imientos| de| program|ación|.||

# %%
events = [
    event
    async for event in composed_chain.astream_events(
        {"topic": "programacion"},
        version="v2",
    )
]

# %%
events
# Out:
# [{'event': 'on_chain_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'RunnableSequence',
#   'tags': [],
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'metadata': {},
#   'parent_ids': []},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_prompt_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'run_id': '20713c24-26c0-40b5-857e-491f306bfded',
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_prompt_end',
#   'data': {'output': ChatPromptValue(messages=[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]),
#    'input': {'topic': 'programacion'}},
#   'run_id': '20713c24-26c0-40b5-857e-491f306bfded',
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chat_model_start',
#   'data': {'input': {'messages': [[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]]}},
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_start',
#   'data': {},
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ''}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¿', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¿'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¿'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¿'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Por', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Por'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Por'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Por'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' qué', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' qué'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' los', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' los'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' program', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' program'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='adores', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'adores'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' od', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' od'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' od'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' od'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='ian', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'ian'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'ian'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'ian'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' la', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' la'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' la'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' la'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' playa', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' playa'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' playa'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' playa'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='?\n', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '?\n'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '?\n'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '?\n'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Por', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Por'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Por'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Por'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='que', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'que'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'que'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'que'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' tienen', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' tienen'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' tienen'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' tienen'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' m', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' m'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' m'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' m'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='iedo', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'iedo'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'iedo'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'iedo'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' de', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' de'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' que', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' que'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' que'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' les', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' les'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' les'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' les'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' sal', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' sal'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' sal'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' sal'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='te', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'te'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'te'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'te'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' un', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' un'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' un'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' un'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' error', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' error'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' error'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' error'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' de', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' de'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' arena', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' arena'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' arena'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' arena'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '.'}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_stream',
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_stream',
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_stream',
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ''}},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_end',
#   'data': {'output': AIMessageChunk(content='¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc'),
#    'input': {'messages': [[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]]}},
#   'run_id': '9f4fe710-017c-4903-9358-237fd6019dcc',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_parser_end',
#   'data': {'output': '¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.',
#    'input': AIMessageChunk(content='¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-9f4fe710-017c-4903-9358-237fd6019dcc')},
#   'run_id': '93230f5e-b880-40d0-9181-1f3375ed4071',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#    'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1']},
#  {'event': 'on_chain_end',
#   'data': {'output': '¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.',
#    'input': {'topic': 'programacion'}},
#   'run_id': 'afaa9acb-f782-4bbc-ac61-6da0bc74c8d1',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#    '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6']},
#  {'event': 'on_chain_end',
#   'data': {'output': {'joke': '¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.'},
#    'input': {'topic': 'programacion'}},
#   'run_id': '1cbbbb99-1f89-4e5d-a3a9-5c2aa0ec44f6',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_prompt_start',
#   'data': {'input': {'joke': '¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.'}},
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:2'],
#   'run_id': 'edaadd1a-9355-45c6-8ebd-af911f085e0f',
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_prompt_end',
#   'data': {'output': ChatPromptValue(messages=[HumanMessage(content='Analiza el chiste: ¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.', additional_kwargs={}, response_metadata={})]),
#    'input': {'joke': '¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.'}},
#   'run_id': 'edaadd1a-9355-45c6-8ebd-af911f085e0f',
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:2'],
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_start',
#   'data': {'input': {'messages': [[HumanMessage(content='Analiza el chiste: ¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.', additional_kwargs={}, response_metadata={})]]}},
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_start',
#   'data': {},
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Este', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
# ...
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' para'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' para'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' aquel', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' aquel'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' aquel'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='los', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'los'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'los'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' familiar', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' familiar'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' familiar'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='izados', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'izados'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'izados'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' con', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' con'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' con'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' el', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' el'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' el'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' mundo', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' mundo'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' mundo'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' de', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' de'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' la', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' la'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' la'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' program', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='ación', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'ación'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'ación'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_stream',
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_stream',
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': []},
#  {'event': 'on_chat_model_end',
#   'data': {'output': AIMessageChunk(content='Este chiste juega con el concepto de errores en la programación y lo relaciona con la playa de una manera humorística. Los programadores suelen tener que lidiar con errores en su código, por lo que el chiste sugiere que incluso en un lugar tan relajante como la playa, podrían encontrarse con un error inesperado, en este caso, un "error de arena". La ironía y el juego de palabras hacen que el chiste sea divertido para aquellos familiarizados con el mundo de la programación.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134'),
#    'input': {'messages': [[HumanMessage(content='Analiza el chiste: ¿Por qué los programadores odian la playa?\nPorque tienen miedo de que les salte un error de arena.', additional_kwargs={}, response_metadata={})]]}},
#   'run_id': 'ae4540bd-960a-45f8-a4e3-013c6f879134',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-3.5-turbo',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.0},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_parser_end',
#   'data': {'output': 'Este chiste juega con el concepto de errores en la programación y lo relaciona con la playa de una manera humorística. Los programadores suelen tener que lidiar con errores en su código, por lo que el chiste sugiere que incluso en un lugar tan relajante como la playa, podrían encontrarse con un error inesperado, en este caso, un "error de arena". La ironía y el juego de palabras hacen que el chiste sea divertido para aquellos familiarizados con el mundo de la programación.',
#    'input': AIMessageChunk(content='Este chiste juega con el concepto de errores en la programación y lo relaciona con la playa de una manera humorística. Los programadores suelen tener que lidiar con errores en su código, por lo que el chiste sugiere que incluso en un lugar tan relajante como la playa, podrían encontrarse con un error inesperado, en este caso, un "error de arena". La ironía y el juego de palabras hacen que el chiste sea divertido para aquellos familiarizados con el mundo de la programación.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'}, id='run-ae4540bd-960a-45f8-a4e3-013c6f879134')},
#   'run_id': '44f74a01-19b4-400d-9b5f-2ccaefd41807',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'parent_ids': ['cb03db45-2e0a-4222-927c-74b6b2a2cc7c']},
#  {'event': 'on_chain_end',
#   'data': {'output': 'Este chiste juega con el concepto de errores en la programación y lo relaciona con la playa de una manera humorística. Los programadores suelen tener que lidiar con errores en su código, por lo que el chiste sugiere que incluso en un lugar tan relajante como la playa, podrían encontrarse con un error inesperado, en este caso, un "error de arena". La ironía y el juego de palabras hacen que el chiste sea divertido para aquellos familiarizados con el mundo de la programación.'},
#   'run_id': 'cb03db45-2e0a-4222-927c-74b6b2a2cc7c',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'parent_ids': []}]

# %%
num_events = 0

async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    kind = event["event"]
    
    if kind == "on_chat_model_stream":
        chunk = event["data"]["chunk"].content
        print(f"Chat model chunk: {repr(chunk)}", flush=True)

    elif kind == "on_parser_stream":
        chunk = event["data"]["chunk"]
        print(f"Parser chunk: {chunk}", flush=True)

    elif kind == "on_chain_stream":
        chunk = event["data"].get("chunk", None)
        if isinstance(chunk, dict):
            for key, value in chunk.items():
                print(f"Chain {key} chunk: {repr(value)}", flush=True)
        else:
            print(f"Chain chunk: {repr(chunk)}", flush=True)

    num_events += 1

    if num_events > 30:  # Truncate output if too many events
        print("...", flush=True)
        break
# Out:
# Chat model chunk: ''
# Parser chunk:
# Chain chunk: ''
# Chain joke chunk: ''
# Chat model chunk: '¿'
# Parser chunk: ¿
# Chain chunk: '¿'
# Chain joke chunk: '¿'
# Chat model chunk: 'Por'
# Parser chunk: Por
# Chain chunk: 'Por'
# Chain joke chunk: 'Por'
# Chat model chunk: ' qué'
# Parser chunk:  qué
# Chain chunk: ' qué'
# Chain joke chunk: ' qué'
# Chat model chunk: ' los'
# Parser chunk:  los
# Chain chunk: ' los'
# Chain joke chunk: ' los'
# Chat model chunk: ' program'
# Parser chunk:  program
# Chain chunk: ' program'
# Chain joke chunk: ' program'
# ...

# %% [markdown]
# #### D. Metodo pipe

# %%
from langchain_core.runnables import RunnableParallel

composed_chain_with_pipe = (
    RunnableParallel({"joke": chain})
    .pipe(analysis_prompt)
    .pipe(model)
    .pipe(StrOutputParser())
)

composed_chain_with_pipe.invoke({"topic": "battlestar galactica"})
# Out:
# 'Este chiste hace referencia a la serie de televisión "Battlestar Galactica", en la cual los Cylons son una raza de robots que buscan exterminar a la humanidad. La broma juega con la idea de que los Cylons son expertos en encontrar a los humanos, ya que tienen la capacidad de "ver" a través de las paredes con sus sensores avanzados. La ironía y el humor negro son elementos presentes en este chiste, ya que se trata de una situación de peligro y amenaza para los humanos, pero se aborda de manera humorística.'

# %%
composed_chain_with_pipe = RunnableParallel({"joke": chain}).pipe(
    analysis_prompt, model, StrOutputParser()
)

chunks = []
for chunk in composed_chain_with_pipe.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| jue|ga| con| el| do|ble| sentido| de| la| palabra| "|bugs|",| que| en| ingl|és| significa| tanto| "|in|sect|os|"| como| "|erro|res| en| un| programa| de| comput|adora|".| La| b|roma| se| bas|a| en| la| idea| de| que| los| program|adores| pref|ieren| el| café| al| té| porque| el| té| tiene| demasi|ados| "|bugs|"| (|erro|res|),| lo| cual| es| una| situación| que| los| program|adores| intent|an| evitar| en| su| trabajo|.| Es| un| ch|iste| s|encil|lo| pero| efect|ivo| para| sac|ar| una| son|ris|a| a| quienes| trabaj|an| en| el| campo| de| la| program|ación|.||
