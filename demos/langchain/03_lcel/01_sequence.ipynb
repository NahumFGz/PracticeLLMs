# %% [markdown]
# ### [How to chain runnables](https://python.langchain.com/docs/how_to/sequence/)

# %%
import getpass
import os

if "LANGCHAIN_API_KEY" not in os.environ:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_API_KEY"] = getpass.getpass()

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# #### A. Model

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template("Cuentame un chiste de {topic}")

chain = prompt | model | StrOutputParser()

# chain.invoke({"topic": "programacion"})
chunks = []
for chunk in chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |¡|Claro|!| Aquí| tienes| uno|:
#
# |¿Por| qué| los| program|adores| pref|ieren| el| café| oscuro|?
#
# |¡|Porque| la| luz| atra|e| a| los| bugs|!| ☕|🐛|
#
# |Espero| que| te| haya| sac|ado| una| sonrisa|.| Si| quieres| otro|,| ¡|d|ím|elo|!||

# %% [markdown]
# #### B. Coercion

# %%
from langchain_core.output_parsers import StrOutputParser

analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}")

composed_chain = {"joke": chain} | analysis_prompt | model | StrOutputParser()

# composed_chain.invoke({"topic": "programacion"})
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| un| par| de| conceptos| que| son| bien| conocidos| en| el| mundo| de| la| programación| y| la| informática|.
#
# |1|.| **|C|afé| oscuro|**|:| La| primera| parte| del| ch|iste| establece| una| prefer|encia| por| el| café| oscuro|,| que| es| una| elección| común| entre| muchas| personas|,| pero| aquí| se| utiliza| como| un| recurso| para| conectar| con| el| contexto| de| los| program|adores|.
#
# |2|.| **|L|uz| y| bugs|**|:| El| núcleo| del| ch|iste| rad|ica| en| el| juego| de| palabras| con| "|bugs|".| En| el| ámbito| de| la| programación|,| "|bugs|"| se| refiere| a| errores| o| fall|os| en| el| código|.| Sin| embargo|,| el| término| "|bug|"| también| hace| referencia| a| insect|os| que|,| en| la| vida| real|,| son| atra|ídos| por| la| luz|.| Este| doble| sentido| crea| una| conexión| humor|ística| entre| la| prefer|encia| del| program|ador| por| el| café| oscuro| y| la| idea| de| que| la| luz| (|que| atra|e| a| los| insect|os|)| también| atra|e| a| los| errores| en| su| código|.
#
# |3|.| **|Hum|or| técnico|**|:| El| ch|iste| es| un| ejemplo| de| humor| técnico|,| que| suele| reson|ar| más| con| personas| que| tienen| experiencia| en| programación|,| ya| que| enti|enden| tanto| el| término| "|bug|"| en| su| contexto| técnico| como| el| juego| de| palabras| que| se| establece|.
#
# |En| resumen|,| el| ch|iste| es| efectivo| porque| combina| un| juego| de| palabras| con| un| concepto| técnico|,| lo| que| lo| hace| divertido| para| quienes| están| familiar|izados| con| el| mundo| de| la| programación|.| Además|,| el| uso| de| emojis| de| café| y| un| insect|o| añade| un| toque| visual| que| complement|a| el| humor|.| ¡|Es| un| buen| ejemplo| de| cómo| el| humor| puede| surgir| de| la| inter|se|cción| de| diferentes| áreas| de| conocimiento|!||

# %% [markdown]
# #### C. Test

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# Paso 1: Crear el primer chain para generar un chiste
joke_prompt = ChatPromptTemplate.from_template("Cuentame un chiste con un máximo de 10 palabras, acerca de {topic}")
joke_chain = joke_prompt | model | StrOutputParser()

# Paso 2: Crear el segundo chain para analizar el chiste
analysis_prompt = ChatPromptTemplate.from_template("Analiza el chiste: {joke}, Inicia con, 'ANALIZANDO EL CHISTE' y finaliza con 'EN RESUMEN: '")
composed_chain = {"joke": joke_chain} | analysis_prompt | model | StrOutputParser()

# Paso 3: Realizar el streaming del composed_chain
chunks = []
for chunk in composed_chain.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |AN|AL|IZ|ANDO| EL| CH|IST|E|:|
#
# |Este| ch|iste| juega| con| un| juego| de| palabras| que| combina| dos| signific|ados|.| Por| un| lado|,| está| la| referencia| al| café|,| una| bebida| popular| entre| los| program|adores| por| su| capacidad| para| mantener|los| despi|ertos| y| concentr|ados| durante| largas| horas| de| trabajo|.| Por| otro| lado|,| "|Java|"| es| el| nombre| de| un| popular| lenguaje| de| programación| utilizado| en| el| desarrollo| de| software|.| La| conexión| entre| el| café| y| "|Java|"| se| establece| a| través| de| la| hom|of|on|ía|,| ya| que| "|java|"| es| también| un| término| colo|quial| para| refer|irse| al| café|,| especialmente| en| algunos| context|os|.
#
# |El| humor| se| deriva| del| doble| sentido|:| el| oy|ente| puede| interpretar| la| frase| de| manera| literal|,| pensando| en| cómo| el| café| ayuda| a| los| program|adores| a| mantenerse| alert|as|,| o| en| un| sentido| más| técnico|,| donde| "|Java|"| se| refiere| al| lenguaje| de| programación|.| Este| tipo| de| ch|istes| es| caracter|ístico| en| el| ámbito| de| la| programación|,| donde| el| conocimiento| específico| de| la| cultura| de| la| programación| y| la| jer|ga| técnica| son| necesarios| para| captar| la| b|roma|.
#
# |Además|,| el| ch|iste| refleja| un| est|ere|otipo| común| acerca| de| los| program|adores|,| sug|iri|endo| que| pasan| mucho| tiempo| trabajando| y|,| por| lo| tanto|,| necesitan| cafe|ína| para| cumplir| con| sus| tareas|.| Esto| también| puede| reson|ar| con| la| experiencia| de| muchas| personas| que| trabajan| en| tecnología|,| haciendo| que| el| ch|iste| sea| más| acces|ible| y| relatable| para| quienes| están| familiar|izados| con| el| entorno|.
#
# |EN| RES|UM|EN|:| El| ch|iste| utiliza| un| juego| de| palabras| entre| el| café| y| el| lenguaje| de| programación| Java|,| creando| humor| a| través| de| la| amb|ig|ü|edad| y| la| relación| entre| la| cultura| de| los| program|adores| y| su| necesaria| ing|esta| de| cafe|ína|.||

# %%
events = []
async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    events.append(event)

event_types = {event["event"] for event in events}
print("Unique event types:", event_types)
# Out:
# Unique event types: {'on_prompt_start', 'on_chain_stream', 'on_parser_end', 'on_prompt_end', 'on_chain_start', 'on_parser_start', 'on_chat_model_end', 'on_chat_model_stream', 'on_parser_stream', 'on_chain_end', 'on_chat_model_start'}

# %%
async for event in composed_chain.astream_events("programacion", version="v2"):
    if event["event"] == "on_chat_model_start":
        print("Stream started...", flush=True)
    elif event["event"] == "on_chat_model_stream":
        print(event["data"]["chunk"].content, end='|', flush=True)
    elif event["event"] == "on_chat_model_end":
        print("\nStream ended...", flush=True)
# Out:
# Stream started...
# |¿Por| qué| los| program|adores| conf|unden| Halloween| y| Navidad|?| ¡|Porque| Oct| |31| es| Dec| |25|!||
# Stream ended...
# Stream started...
# |AN|AL|IZ|ANDO| EL| CH|IST|E|:
#
# |Este| ch|iste| juega| con| el| conocimiento| de| sistemas| num|ér|icos| y| las| convenc|iones| que| se| utilizan| en| programación|.| En| él|,| se| menc|iona| que| los| program|adores| conf|unden| Halloween| (|31| de| octubre|)| y| Navidad| (|25| de| diciembre|)| debido| a| una| relación| num|érica| entre| las| fechas|.| La| clave| del| ch|iste| rad|ica| en| la| interpretación| de| los| números| en| diferentes| bases|:
#
# |-| "|Oct| |31|"| se| refiere| a| "|31| en| base| oct|al|"| (|base| |8|),| que| en| el| sistema| decimal| (|base| |10|)| equiv|ale| a| |25|.
# |-| "|Dec| |25|"| se| refiere| a| "|25| en| base| decimal|"| (|base| |10|).
#
# |La| conf|usión| surge| porque| "|Oct|"| y| "|Dec|"| también| se| pueden| interpretar| como| abre|vi|aturas| de| "|oct|al|"| y| "|decimal|",| respectivamente|.| Por| lo| tanto|,| el| ch|iste| no| solo| es| un| juego| de| palabras|,| sino| que| también| establece| una| conexión| humor|ística| entre| conceptos| técnicos| de| programación| y| las| festiv|idades|.
#
# |El| humor| es| efectivo| para| quienes| tienen| conocimientos| de| programación| o| matem|áticas|,| ya| que| el| ch|iste| requiere| un| entend|imiento| de| las| bases| num|éricas| para| apreci|arlo| completamente|.| Para| aquellos| que| no| están| familiar|izados| con| estos| conceptos|,| el| ch|iste| puede| resultar| conf|uso|,| lo| que| añade| una| capa| de| exclus|ividad| al| humor|.
#
# |EN| RES|UM|EN|:| El| ch|iste| es| una| b|roma| técnica| que| juega| con| el| concepto| de| bases| num|éricas| en| programación|,| donde| "|Oct| |31|"| (|31| en| oct|al|)| es| igual| a| "|Dec| |25|"| (|25| en| decimal|),| aprovech|ando| la| conf|usión| entre| las| festiv|idades| y| la| termin|ología| de| programación| para| generar| humor|.||
# Stream ended...

# %%
events = [
    event
    async for event in composed_chain.astream_events(
        {"topic": "programacion"},
        version="v2",
    )
]

# %%
events
# Out:
# [{'event': 'on_chain_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'RunnableSequence',
#   'tags': [],
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'metadata': {},
#   'parent_ids': []},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'metadata': {},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_start',
#   'data': {},
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'metadata': {},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_prompt_start',
#   'data': {'input': {'topic': 'programacion'}},
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'run_id': '2d5494f1-d3e7-4cd8-879a-99815ff5ebe0',
#   'metadata': {},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_prompt_end',
#   'data': {'output': ChatPromptValue(messages=[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]),
#    'input': {'topic': 'programacion'}},
#   'run_id': '2d5494f1-d3e7-4cd8-879a-99815ff5ebe0',
#   'name': 'ChatPromptTemplate',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chat_model_start',
#   'data': {'input': {'messages': [[HumanMessage(content='Cuentame un chiste de programacion', additional_kwargs={}, response_metadata={})]]}},
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_start',
#   'data': {},
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'metadata': {},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ''}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¡', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¡'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¡'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Claro', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Claro'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Claro'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Claro'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '!'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '!'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '!'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Aquí', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Aquí'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Aquí'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Aquí'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' tienes', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' tienes'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' tienes'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' tienes'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' uno', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' uno'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' uno'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' uno'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ':\n\n'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ':\n\n'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ':\n\n'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='¿Por', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '¿Por'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '¿Por'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '¿Por'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' qué', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' qué'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' qué'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' los', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' los'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' los'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' program', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' program'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' program'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='adores', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'adores'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'adores'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' conf', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' conf'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' conf'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' conf'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='unden', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'unden'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'unden'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'unden'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Halloween', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Halloween'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Halloween'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Halloween'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' y', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' y'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' y'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' y'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Navidad', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Navidad'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Navidad'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Navidad'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='?\n\n', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '?\n\n'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '?\n\n'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '?\n\n'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='Porque', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': 'Porque'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': 'Porque'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': 'Porque'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Oct', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Oct'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Oct'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Oct'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' '}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='31', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '31'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '31'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '31'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' es', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' es'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' es'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' es'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' igual', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' igual'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' igual'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' igual'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' a'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' a'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' a'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' Dec', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' Dec'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' Dec'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' Dec'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' '},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' '}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='25', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '25'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '25'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '25'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': '.'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' \n\n', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': ' \n\n'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': ' \n\n'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a']},
#  {'event': 'on_chain_stream',
#   'run_id': 'df56a401-b888-45e3-9e52-321d8fc28b9a',
#   'name': 'RunnableParallel<joke>',
#   'tags': ['seq:step:1'],
#   'metadata': {},
#   'data': {'chunk': {'joke': ' \n\n'}},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='(', additional_kwargs={}, response_metadata={}, id='run-2af0dee5-89f6-4a6f-8551-d5f425519e95')},
#   'run_id': '2af0dee5-89f6-4a6f-8551-d5f425519e95',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:2'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_parser_stream',
#   'run_id': 'e690d2e0-c576-4eef-9129-a5569e844602',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:3'],
#   'metadata': {},
#   'data': {'chunk': '('},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#    'df56a401-b888-45e3-9e52-321d8fc28b9a',
#    'f578e6c4-215c-4120-a2dc-86e48585f702']},
#  {'event': 'on_chain_stream',
#   'run_id': 'f578e6c4-215c-4120-a2dc-86e48585f702',
#   'name': 'RunnableSequence',
#   'tags': ['map:key:joke'],
#   'metadata': {},
#   'data': {'chunk': '('},
# ...
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' especialmente'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' especialmente'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' divertido', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' divertido'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' divertido'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' para', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' para'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' para'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' aquellos', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' aquellos'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' aquellos'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' con', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' con'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' con'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' un', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' un'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' un'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' tras', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' tras'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' tras'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='f', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'f'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'f'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='ondo', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': 'ondo'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': 'ondo'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content=' técnico', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ' técnico'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ' técnico'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': '.'},
#   'parent_ids': []},
#  {'event': 'on_chat_model_stream',
#   'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b'}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_stream',
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_stream',
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'data': {'chunk': ''},
#   'parent_ids': []},
#  {'event': 'on_chat_model_end',
#   'data': {'output': AIMessageChunk(content='Este chiste juega con la ambigüedad de las notaciones numéricas en programación. La confusión entre Halloween y Navidad se basa en que, en el sistema octal (base 8), el número 31 representa el valor decimal 25. \n\n- **Oct 31**: En notación octal, el número 31 se descompone como \\(3 \\times 8^1 + 1 \\times 8^0 = 24 + 1 = 25\\) en decimal.\n- **Dec 25**: En notación decimal, simplemente es el número 25.\n\nLa broma radica en que los programadores, que suelen estar familiarizados con diferentes bases numéricas, pueden ver la equivalencia entre estos dos números y, por ende, hacer la conexión humorística entre dos festividades que son muy distintas: Halloween (31 de octubre) y Navidad (25 de diciembre).\n\nEN RESUMEN: El chiste utiliza el conocimiento de las bases numéricas en programación para crear un juego de palabras que vincula dos festividades a través de una equivalencia matemática, lo que lo hace especialmente divertido para aquellos con un trasfondo técnico.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b'}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61'),
#    'input': {'messages': [[HumanMessage(content='Analiza el chiste: ¡Claro! Aquí tienes uno:\n\n¿Por qué los programadores confunden Halloween y Navidad?\n\nPorque Oct 31 es igual a Dec 25. \n\n(En programación, "Oct" es la notación octal y "Dec" es la notación decimal. ¡Es un juego de números!), finaliza con \'EN RESUMEN: \'', additional_kwargs={}, response_metadata={})]]}},
#   'run_id': '4a6af3bd-2278-4e41-96c8-551fe6fc7d61',
#   'name': 'ChatOpenAI',
#   'tags': ['seq:step:3'],
#   'metadata': {'ls_provider': 'openai',
#    'ls_model_name': 'gpt-4o-mini',
#    'ls_model_type': 'chat',
#    'ls_temperature': 0.7},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_parser_end',
#   'data': {'output': 'Este chiste juega con la ambigüedad de las notaciones numéricas en programación. La confusión entre Halloween y Navidad se basa en que, en el sistema octal (base 8), el número 31 representa el valor decimal 25. \n\n- **Oct 31**: En notación octal, el número 31 se descompone como \\(3 \\times 8^1 + 1 \\times 8^0 = 24 + 1 = 25\\) en decimal.\n- **Dec 25**: En notación decimal, simplemente es el número 25.\n\nLa broma radica en que los programadores, que suelen estar familiarizados con diferentes bases numéricas, pueden ver la equivalencia entre estos dos números y, por ende, hacer la conexión humorística entre dos festividades que son muy distintas: Halloween (31 de octubre) y Navidad (25 de diciembre).\n\nEN RESUMEN: El chiste utiliza el conocimiento de las bases numéricas en programación para crear un juego de palabras que vincula dos festividades a través de una equivalencia matemática, lo que lo hace especialmente divertido para aquellos con un trasfondo técnico.',
#    'input': AIMessageChunk(content='Este chiste juega con la ambigüedad de las notaciones numéricas en programación. La confusión entre Halloween y Navidad se basa en que, en el sistema octal (base 8), el número 31 representa el valor decimal 25. \n\n- **Oct 31**: En notación octal, el número 31 se descompone como \\(3 \\times 8^1 + 1 \\times 8^0 = 24 + 1 = 25\\) en decimal.\n- **Dec 25**: En notación decimal, simplemente es el número 25.\n\nLa broma radica en que los programadores, que suelen estar familiarizados con diferentes bases numéricas, pueden ver la equivalencia entre estos dos números y, por ende, hacer la conexión humorística entre dos festividades que son muy distintas: Halloween (31 de octubre) y Navidad (25 de diciembre).\n\nEN RESUMEN: El chiste utiliza el conocimiento de las bases numéricas en programación para crear un juego de palabras que vincula dos festividades a través de una equivalencia matemática, lo que lo hace especialmente divertido para aquellos con un trasfondo técnico.', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b'}, id='run-4a6af3bd-2278-4e41-96c8-551fe6fc7d61')},
#   'run_id': '8a6e628a-21a4-45c2-b586-c7b6c0fae72f',
#   'name': 'StrOutputParser',
#   'tags': ['seq:step:4'],
#   'metadata': {},
#   'parent_ids': ['e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc']},
#  {'event': 'on_chain_end',
#   'data': {'output': 'Este chiste juega con la ambigüedad de las notaciones numéricas en programación. La confusión entre Halloween y Navidad se basa en que, en el sistema octal (base 8), el número 31 representa el valor decimal 25. \n\n- **Oct 31**: En notación octal, el número 31 se descompone como \\(3 \\times 8^1 + 1 \\times 8^0 = 24 + 1 = 25\\) en decimal.\n- **Dec 25**: En notación decimal, simplemente es el número 25.\n\nLa broma radica en que los programadores, que suelen estar familiarizados con diferentes bases numéricas, pueden ver la equivalencia entre estos dos números y, por ende, hacer la conexión humorística entre dos festividades que son muy distintas: Halloween (31 de octubre) y Navidad (25 de diciembre).\n\nEN RESUMEN: El chiste utiliza el conocimiento de las bases numéricas en programación para crear un juego de palabras que vincula dos festividades a través de una equivalencia matemática, lo que lo hace especialmente divertido para aquellos con un trasfondo técnico.'},
#   'run_id': 'e99215c1-d6ba-4b9f-bc24-c0ea6bf281dc',
#   'name': 'RunnableSequence',
#   'tags': [],
#   'metadata': {},
#   'parent_ids': []}]

# %%
num_events = 0

async for event in composed_chain.astream_events({"topic": "programacion"}, version="v2"):
    kind = event["event"]
    
    if kind == "on_chat_model_stream":
        chunk = event["data"]["chunk"].content
        print(f"Chat model chunk: {repr(chunk)}", flush=True)

    elif kind == "on_parser_stream":
        chunk = event["data"]["chunk"]
        print(f"Parser chunk: {chunk}", flush=True)

    elif kind == "on_chain_stream":
        chunk = event["data"].get("chunk", None)
        if isinstance(chunk, dict):
            for key, value in chunk.items():
                print(f"Chain {key} chunk: {repr(value)}", flush=True)
        else:
            print(f"Chain chunk: {repr(chunk)}", flush=True)

    num_events += 1

    if num_events > 30:  # Truncate output if too many events
        print("...", flush=True)
        break
# Out:
# Chat model chunk: ''
# Parser chunk:
# Chain chunk: ''
# Chain joke chunk: ''
# Chat model chunk: '¡'
# Parser chunk: ¡
# Chain chunk: '¡'
# Chain joke chunk: '¡'
# Chat model chunk: 'Claro'
# Parser chunk: Claro
# Chain chunk: 'Claro'
# Chain joke chunk: 'Claro'
# Chat model chunk: '!'
# Parser chunk: !
# Chain chunk: '!'
# Chain joke chunk: '!'
# Chat model chunk: ' Aquí'
# Parser chunk:  Aquí
# Chain chunk: ' Aquí'
# Chain joke chunk: ' Aquí'
# Chat model chunk: ' tienes'
# Parser chunk:  tienes
# Chain chunk: ' tienes'
# Chain joke chunk: ' tienes'
# ...

# %% [markdown]
# #### D. Metodo pipe

# %%
from langchain_core.runnables import RunnableParallel

composed_chain_with_pipe = (
    RunnableParallel({"joke": chain})
    .pipe(analysis_prompt)
    .pipe(model)
    .pipe(StrOutputParser())
)

composed_chain_with_pipe.invoke({"topic": "battlestar galactica"})
# Out:
# 'El chiste se basa en la premisa de la serie "Battlestar Galactica", donde los cylons son seres artificiales diseñados para cazar y exterminar a la humanidad. La broma juega con la idea de que, debido a su naturaleza y habilidades, los cylons serían extremadamente efectivos en un juego como las escondidas, donde el objetivo es encontrar a los demás jugadores.\n\nEl humor proviene de la exageración de la capacidad de los cylons para localizar a los humanos, convirtiendo una situación lúdica en una referencia a su papel como antagonistas en la serie. La incongruencia entre la seriedad del contexto (la caza de humanos) y la ligereza del juego (escondidas) crea un efecto cómico.\n\nEN RESUMEN: El chiste utiliza la conexión entre los cylons y su habilidad para encontrar humanos para recontextualizar un juego infantil, generando humor a través de la ironía y la exageración.'

# %%
composed_chain_with_pipe = RunnableParallel({"joke": chain}).pipe(
    analysis_prompt, model, StrOutputParser()
)

chunks = []
for chunk in composed_chain_with_pipe.stream({"topic": "programacion"}):
    chunks.append(chunk)
    print(chunk, end='|', flush=True)
# Out:
# |Este| ch|iste| juega| con| el| doble| sentido| de| la| palabra| "|light|".| Por| un| lado|,| se| refiere| a| la| prefer|encia| de| los| program|adores| por| el| café| oscuro|,| que| es| más| fuerte| y| concentr|ado|,| lo| que| podría| asoci|arse| con| la| necesidad| de| energía| para| realizar| su| trabajo|.| Por| otro| lado|,| "|light|"| también| puede| refer|irse| a| un| código| que| es| poco| d|enso| o| fácil|,| lo| cual| puede| interpret|arse| como| un| código| que| no| es| lo| suficientemente| robust|o| o| efectivo|.|
#
# |La| b|roma| su|gi|ere| que| los| program|adores| pref|ieren| un| café| que| les| mant|enga| alerta| y| enf|ocados|,| al| igual| que| buscan| que| su| código| sea| sólido| y| no| "|lig|ero|"| o| superficial|.| El| juego| de| palabras| añade| un| toque| de| humor| que| puede| reson|ar| especialmente| con| quienes| están| familiar|izados| con| la| programación| y| su| cultura|.
#
# |EN| RES|UM|EN|:| El| ch|iste| utiliza| un| juego| de| palabras| entre| "|light|"| como| café| ligero| y| un| código| poco| d|enso|,| refle|j|ando| la| prefer|encia| de| los| program|adores| por| lo| fuerte| y| efectivo|,| tanto| en| su| bebida| como| en| su| trabajo|.||
