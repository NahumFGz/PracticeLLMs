# %% [markdown]
# ### Replica 4: Limpieza de multiples fuentes de datos, joiner, cleaner y al final escribir en memoria

# %%
from haystack.components.writers import DocumentWriter
from haystack.components.converters import MarkdownToDocument, PyPDFToDocument, TextFileToDocument
from haystack.components.preprocessors import DocumentCleaner, DocumentSplitter
from haystack.components.routers import FileTypeRouter
from haystack.components.joiners import DocumentJoiner
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.embedders import SentenceTransformersDocumentEmbedder

document_store = InMemoryDocumentStore()

file_type_router = FileTypeRouter(mime_types=["text/markdown", "application/pdf", "text/plain"])
text_file_converter = TextFileToDocument()
markdown_converter = MarkdownToDocument()
pdf_converter = PyPDFToDocument()

document_joiner = DocumentJoiner()
document_cleaner = DocumentCleaner()
document_splitter = DocumentSplitter(split_by="word", split_length=150, split_overlap=50)

document_embedder = SentenceTransformersDocumentEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")
document_writer = DocumentWriter(document_store=document_store)

# %%
from haystack import Pipeline

pipeline = Pipeline()
pipeline.add_component(name="file_type_router", instance=file_type_router)
pipeline.add_component(name="text_file_converter", instance=text_file_converter)
pipeline.add_component(name="markdown_converter", instance=markdown_converter)
pipeline.add_component(name="pypdf_converter", instance=pdf_converter)
pipeline.add_component(name="document_joiner", instance=document_joiner)
pipeline.add_component(name="document_cleaner", instance=document_cleaner)
pipeline.add_component(name="document_splitter", instance=document_splitter)
pipeline.add_component(name="document_embedder", instance=document_embedder)
pipeline.add_component(name="document_writer", instance=document_writer)

# %%
pipeline.connect("file_type_router.text/plain", "text_file_converter.sources")
pipeline.connect("file_type_router.application/pdf", "pypdf_converter.sources")
pipeline.connect("file_type_router.text/markdown", "markdown_converter.sources")
pipeline.connect("text_file_converter", "document_joiner")
pipeline.connect("pypdf_converter", "document_joiner")
pipeline.connect("markdown_converter", "document_joiner")
pipeline.connect("document_joiner", "document_cleaner")
pipeline.connect("document_cleaner", "document_splitter")
pipeline.connect("document_splitter", "document_embedder")
pipeline.connect("document_embedder", "document_writer")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7f2fde713150>
# 🚅 Components
#   - file_type_router: FileTypeRouter
#   - text_file_converter: TextFileToDocument
#   - markdown_converter: MarkdownToDocument
#   - pypdf_converter: PyPDFToDocument
#   - document_joiner: DocumentJoiner
#   - document_cleaner: DocumentCleaner
#   - document_splitter: DocumentSplitter
#   - document_embedder: SentenceTransformersDocumentEmbedder
#   - document_writer: DocumentWriter
# 🛤️ Connections
#   - file_type_router.text/plain -> text_file_converter.sources (List[Union[str, Path, ByteStream]])
#   - file_type_router.application/pdf -> pypdf_converter.sources (List[Union[str, Path, ByteStream]])
#   - file_type_router.text/markdown -> markdown_converter.sources (List[Union[str, Path, ByteStream]])
#   - text_file_converter.documents -> document_joiner.documents (List[Document])
#   - markdown_converter.documents -> document_joiner.documents (List[Document])
#   - pypdf_converter.documents -> document_joiner.documents (List[Document])
#   - document_joiner.documents -> document_cleaner.documents (List[Document])
#   - document_cleaner.documents -> document_splitter.documents (List[Document])
#   - document_splitter.documents -> document_embedder.documents (List[Document])
#   - document_embedder.documents -> document_writer.documents (List[Document])

# %%
from pathlib import Path
output_dir = "../tutorials/recipe_files"

pipeline.run({"file_type_router": {"sources": list(Path(output_dir).glob("**/*"))}})

# %%
# import logging

# logging.basicConfig(level=logging.DEBUG)  # Configurar nivel de logs

# # Ahora al ejecutar el pipeline, se mostrarán logs detallados
# pipeline.run({"file_type_router": {"sources": list(Path(output_dir).glob("**/*"))}})
# Out:
# INFO:haystack.core.pipeline.base:Warming up component document_embedder...
# /home/nahumfg/GithubProjects/TesisMaestria/TesisHaystack/venv_haystack_ai/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:195: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v4 of SentenceTransformers.
#   warnings.warn(
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): eu.i.posthog.com:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json HTTP/11" 404 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json HTTP/11" 200 0
# DEBUG:urllib3.connectionpool:https://eu.i.posthog.com:443 "POST /batch/ HTTP/11" 200 15
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /api/models/sentence-transformers/all-MiniLM-L6-v2/revision/main HTTP/11" 200 6694
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /api/models/sentence-transformers/all-MiniLM-L6-v2 HTTP/11" 200 6694
# INFO:haystack.core.pipeline.pipeline:Running component file_type_router
# INFO:haystack.core.pipeline.pipeline:Running component text_file_converter
# INFO:haystack.core.pipeline.pipeline:Running component pypdf_converter
# INFO:haystack.core.pipeline.pipeline:Running component markdown_converter
# Converting markdown files to Documents:   0%|          | 0/1 [00:00<?, ?it/s]DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=0,level=0,tokens=0), 0, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=1,level=0,tokens=3), 1, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=3,level=0,tokens=6), 3, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=5,level=0,tokens=9), 5, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=5,level=0,tokens=9), 6, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=0,tokens=12), 6, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=0,tokens=12), 6, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=0,tokens=12), 6, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=0,tokens=12), 6, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=0,tokens=12), 6, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=6,level=2,tokens=14), 6, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=6,level=2,tokens=14), 7, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=7,level=1,tokens=18), 7, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=7,level=1,tokens=18), 7, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=7,level=1,tokens=18), 7, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=7,level=2,tokens=19), 7, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=10,level=1,tokens=23), 10, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=10,level=1,tokens=23), 10, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=10,level=1,tokens=23), 10, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=10,level=0,tokens=24), 10, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=10,level=0,tokens=24), 11, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=11,level=0,tokens=27), 11, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=11,level=0,tokens=27), 11, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=11,level=0,tokens=27), 11, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=11,level=0,tokens=27), 11, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=11,level=0,tokens=27), 11, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=11,level=2,tokens=29), 11, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=11,level=2,tokens=29), 12, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=12,level=1,tokens=33), 12, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=12,level=1,tokens=33), 12, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=12,level=1,tokens=33), 12, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=12,level=2,tokens=34), 12, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=12,level=2,tokens=34), 13, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=13,level=1,tokens=38), 13, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=13,level=1,tokens=38), 13, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=13,level=1,tokens=38), 13, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=13,level=2,tokens=39), 13, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=13,level=2,tokens=39), 14, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=14,level=1,tokens=43), 14, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=14,level=1,tokens=43), 14, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=14,level=1,tokens=43), 14, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=14,level=2,tokens=44), 14, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=14,level=2,tokens=44), 15, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=15,level=1,tokens=48), 15, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=15,level=1,tokens=48), 15, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=15,level=1,tokens=48), 15, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=15,level=2,tokens=49), 15, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=15,level=2,tokens=49), 16, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=16,level=1,tokens=53), 16, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=16,level=1,tokens=53), 16, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=16,level=1,tokens=53), 16, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=16,level=2,tokens=54), 16, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=16,level=2,tokens=54), 17, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=17,level=1,tokens=58), 17, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=17,level=1,tokens=58), 17, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=17,level=1,tokens=58), 17, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=17,level=2,tokens=59), 17, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=17,level=2,tokens=59), 18, 38, True
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=18,level=1,tokens=63), 18, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=18,level=1,tokens=63), 18, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=18,level=1,tokens=63), 18, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=18,level=2,tokens=64), 18, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=20,level=1,tokens=68), 20, 38, True
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=20,level=1,tokens=68), 20, 38, True
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=20,level=1,tokens=68), 20, 38, True
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=20,level=0,tokens=69), 20, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=21,level=0,tokens=72), 21, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=23,level=0,tokens=75), 23, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=25,level=0,tokens=78), 25, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=27,level=0,tokens=81), 27, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=29,level=0,tokens=84), 29, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=31,level=0,tokens=87), 31, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=33,level=0,tokens=90), 33, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=35,level=0,tokens=93), 35, 38, False
# DEBUG:markdown_it.rules_block.code:entering code: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.fence:entering fence: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.blockquote:entering blockquote: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.hr:entering hr: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.list:entering list: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.reference:entering reference: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.html_block:entering html_block: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.heading:entering heading: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.lheading:entering lheading: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# DEBUG:markdown_it.rules_block.paragraph:entering paragraph: StateBlock(line=37,level=0,tokens=96), 37, 38, False
# Converting markdown files to Documents: 100%|██████████| 1/1 [00:00<00:00,  6.09it/s]
# INFO:haystack.core.pipeline.pipeline:Running component document_joiner
# INFO:haystack.components.joiners.document_joiner:Some of the Documents DocumentJoiner got have score=None. It was configured to sort Documents by score, so those with score=None were sorted as if they had a score of -infinity.
# INFO:haystack.core.pipeline.pipeline:Running component document_cleaner
# INFO:haystack.core.pipeline.pipeline:Running component document_splitter
# INFO:haystack.core.pipeline.pipeline:Running component document_embedder
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:haystack.core.pipeline.pipeline:Running component document_writer
# {'document_writer': {'documents_written': 14}}
